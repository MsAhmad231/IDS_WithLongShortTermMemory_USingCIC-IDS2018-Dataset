# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive

# copy the .zip file into the root directory of cloud VM
# !cp /content/gdrive/MyDrive/dataset.zip ../

# unzip the zip file and its contents should now be in /darknet/data/obj
# !unzip ../dataset.zip
# Out:
# 'Arsitektur ANN.png'
# 'Arsitektur LSTM.drawio'
#  Classroom
# 'Colab Notebooks'
#  dataset
#  Dataset_mutia.csv
#  dataset.zip
# 'DDoS_LSTM_Model_53 Fitur.ipynb'
#  DDoS_LSTM_Model_69_Fitur_50_50.ipynb
#  hasil.zip
# 'koding dan hasil'
# 'koding ta2'
# 'My Drive'
# 'Salinan DDoS_LSTM_Model_69_Fitur_50_50.ipynb'
# 'Untitled Diagram (1).drawio'
# 'Untitled Diagram.drawio'
# Archive:  ../dataset.zip
#    creating: dataset/
#   inflating: dataset/testdata_10.csv
#   inflating: dataset/testdata_20.csv
#   inflating: dataset/testdata_30.csv
#   inflating: dataset/testdata_40.csv
#   inflating: dataset/testdata_50.csv
#   inflating: dataset/traindata_50.csv
#   inflating: dataset/traindata_60.csv
#   inflating: dataset/traindata_70.csv
#   inflating: dataset/traindata_80.csv
#   inflating: dataset/traindata_90.csv

# %%
from __future__ import print_function
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
np.random.seed(1337)  # for reproducibility
from keras.preprocessing import sequence
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Embedding
from keras.layers import LSTM, SimpleRNN, GRU
from keras.datasets import imdb
from keras.utils.np_utils import to_categorical
from sklearn.metrics import (precision_score, recall_score,f1_score, accuracy_score,mean_squared_error,mean_absolute_error)
from sklearn import metrics
from sklearn.preprocessing import Normalizer
import h5py
from keras import callbacks
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

# %%
traindata = pd.read_csv('dataset/traindata_80.csv')
testdata = pd.read_csv('dataset/testdata_20.csv')

# %%
traindata.drop(['Unnamed: 0','Timestamp'], axis = 1, inplace=True)
testdata.drop(['Unnamed: 0','Timestamp'], axis = 1, inplace=True)

# %%
traindata = traindata.replace(to_replace = ["DDOS attack-HOIC"],value = 1)
traindata = traindata.replace(to_replace = ["Benign"],value = 0)
testdata = testdata.replace(to_replace = ["DDOS attack-HOIC"],value = 1)
testdata = testdata.replace(to_replace = ["Benign"],value = 0)

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor1 = traindata.corr()
sns.heatmap(cor1, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
a = abs(cor1['Label'])
result = a[a > 0.1]
result
# Out:
# Dst Port             0.990373
# Tot Fwd Pkts         0.932724
# Tot Bwd Pkts         0.332853
# TotLen Fwd Pkts      0.963413
# TotLen Bwd Pkts      0.109457
# Fwd Pkt Len Max      0.964809
# Fwd Pkt Len Mean     0.907615
# Fwd Pkt Len Std      0.942592
# Bwd Pkt Len Max      0.109346
# Bwd Pkt Len Mean     0.477858
# Bwd Pkt Len Std      0.279051
# Flow Byts/s          0.687237
# Flow Pkts/s          0.288454
# Bwd IAT Min          0.130485
# Fwd Header Len       0.948810
# Bwd Header Len       0.256304
# Fwd Pkts/s           0.215512
# Bwd Pkts/s           0.438120
# Pkt Len Max          0.718727
# Pkt Len Mean         0.718462
# Pkt Len Std          0.717935
# Pkt Len Var          0.717859
# RST Flag Cnt         0.717707
# PSH Flag Cnt         0.718378
# ACK Flag Cnt         0.723589
# ECE Flag Cnt         0.717707
# Down/Up Ratio        0.311220
# Pkt Size Avg         0.718114
# Fwd Seg Size Avg     0.907615
# Bwd Seg Size Avg     0.477858
# Subflow Fwd Pkts     0.932724
# Subflow Fwd Byts     0.963413
# Subflow Bwd Pkts     0.332853
# Subflow Bwd Byts     0.109457
# Init Fwd Win Byts    0.706186
# Init Bwd Win Byts    0.995151
# Fwd Act Data Pkts    0.547840
# Label                1.000000
# Name: Label, dtype: float64

# %%
traindata.drop(['Protocol','Flow Byts/s','Flow Pkts/s','Pkt Len Min','Fwd Byts/b Avg','Fwd Pkts/b Avg','Fwd Blk Rate Avg','Bwd Byts/b Avg','Bwd Pkts/b Avg','Bwd Blk Rate Avg','Fwd Seg Size Min','Active Mean','Active Std','Active Max','Active Min','Idle Mean','Idle Std','Idle Max','Idle Min','FIN Flag Cnt','SYN Flag Cnt','URG Flag Cnt','CWE Flag Count','Flow Duration'], axis = 1, inplace=True)
testdata.drop(['Protocol','Flow Byts/s','Flow Pkts/s','Pkt Len Min','Fwd Byts/b Avg','Fwd Pkts/b Avg','Fwd Blk Rate Avg','Bwd Byts/b Avg','Bwd Pkts/b Avg','Bwd Blk Rate Avg','Fwd Seg Size Min','Active Mean','Active Std','Active Max','Active Min','Idle Mean','Idle Std','Idle Max','Idle Min','FIN Flag Cnt','SYN Flag Cnt','URG Flag Cnt','CWE Flag Count','Flow Duration'], axis = 1, inplace=True)

# %%
enc = LabelEncoder()
traindata = traindata.apply(enc.fit_transform)
testdata = testdata.apply(enc.fit_transform)

# %%
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 837476 entries, 0 to 837475
# Data columns (total 55 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Dst Port           837476 non-null  int64
#  1   Tot Fwd Pkts       837476 non-null  int64
#  2   Tot Bwd Pkts       837476 non-null  int64
#  3   TotLen Fwd Pkts    837476 non-null  int64
#  4   TotLen Bwd Pkts    837476 non-null  int64
#  5   Fwd Pkt Len Max    837476 non-null  int64
#  6   Fwd Pkt Len Min    837476 non-null  int64
#  7   Fwd Pkt Len Mean   837476 non-null  int64
#  8   Fwd Pkt Len Std    837476 non-null  int64
#  9   Bwd Pkt Len Max    837476 non-null  int64
#  10  Bwd Pkt Len Min    837476 non-null  int64
#  11  Bwd Pkt Len Mean   837476 non-null  int64
#  12  Bwd Pkt Len Std    837476 non-null  int64
#  13  Flow IAT Mean      837476 non-null  int64
#  14  Flow IAT Std       837476 non-null  int64
#  15  Flow IAT Max       837476 non-null  int64
#  16  Flow IAT Min       837476 non-null  int64
#  17  Fwd IAT Tot        837476 non-null  int64
#  18  Fwd IAT Mean       837476 non-null  int64
#  19  Fwd IAT Std        837476 non-null  int64
#  20  Fwd IAT Max        837476 non-null  int64
#  21  Fwd IAT Min        837476 non-null  int64
#  22  Bwd IAT Tot        837476 non-null  int64
#  23  Bwd IAT Mean       837476 non-null  int64
#  24  Bwd IAT Std        837476 non-null  int64
#  25  Bwd IAT Max        837476 non-null  int64
#  26  Bwd IAT Min        837476 non-null  int64
#  27  Fwd PSH Flags      837476 non-null  int64
#  28  Bwd PSH Flags      837476 non-null  int64
#  29  Fwd URG Flags      837476 non-null  int64
#  30  Bwd URG Flags      837476 non-null  int64
#  31  Fwd Header Len     837476 non-null  int64
#  32  Bwd Header Len     837476 non-null  int64
#  33  Fwd Pkts/s         837476 non-null  int64
#  34  Bwd Pkts/s         837476 non-null  int64
#  35  Pkt Len Max        837476 non-null  int64
#  36  Pkt Len Mean       837476 non-null  int64
#  37  Pkt Len Std        837476 non-null  int64
#  38  Pkt Len Var        837476 non-null  int64
#  39  RST Flag Cnt       837476 non-null  int64
#  40  PSH Flag Cnt       837476 non-null  int64
#  41  ACK Flag Cnt       837476 non-null  int64
#  42  ECE Flag Cnt       837476 non-null  int64
#  43  Down/Up Ratio      837476 non-null  int64
#  44  Pkt Size Avg       837476 non-null  int64
#  45  Fwd Seg Size Avg   837476 non-null  int64
#  46  Bwd Seg Size Avg   837476 non-null  int64
#  47  Subflow Fwd Pkts   837476 non-null  int64
#  48  Subflow Fwd Byts   837476 non-null  int64
#  49  Subflow Bwd Pkts   837476 non-null  int64
#  50  Subflow Bwd Byts   837476 non-null  int64
#  51  Init Fwd Win Byts  837476 non-null  int64
#  52  Init Bwd Win Byts  837476 non-null  int64
#  53  Fwd Act Data Pkts  837476 non-null  int64
#  54  Label              837476 non-null  int64
# dtypes: int64(55)
# memory usage: 351.4 MB

# %%
testdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209368 entries, 0 to 209367
# Data columns (total 55 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Dst Port           209368 non-null  int64
#  1   Tot Fwd Pkts       209368 non-null  int64
#  2   Tot Bwd Pkts       209368 non-null  int64
#  3   TotLen Fwd Pkts    209368 non-null  int64
#  4   TotLen Bwd Pkts    209368 non-null  int64
#  5   Fwd Pkt Len Max    209368 non-null  int64
#  6   Fwd Pkt Len Min    209368 non-null  int64
#  7   Fwd Pkt Len Mean   209368 non-null  int64
#  8   Fwd Pkt Len Std    209368 non-null  int64
#  9   Bwd Pkt Len Max    209368 non-null  int64
#  10  Bwd Pkt Len Min    209368 non-null  int64
#  11  Bwd Pkt Len Mean   209368 non-null  int64
#  12  Bwd Pkt Len Std    209368 non-null  int64
#  13  Flow IAT Mean      209368 non-null  int64
#  14  Flow IAT Std       209368 non-null  int64
#  15  Flow IAT Max       209368 non-null  int64
#  16  Flow IAT Min       209368 non-null  int64
#  17  Fwd IAT Tot        209368 non-null  int64
#  18  Fwd IAT Mean       209368 non-null  int64
#  19  Fwd IAT Std        209368 non-null  int64
#  20  Fwd IAT Max        209368 non-null  int64
#  21  Fwd IAT Min        209368 non-null  int64
#  22  Bwd IAT Tot        209368 non-null  int64
#  23  Bwd IAT Mean       209368 non-null  int64
#  24  Bwd IAT Std        209368 non-null  int64
#  25  Bwd IAT Max        209368 non-null  int64
#  26  Bwd IAT Min        209368 non-null  int64
#  27  Fwd PSH Flags      209368 non-null  int64
#  28  Bwd PSH Flags      209368 non-null  int64
#  29  Fwd URG Flags      209368 non-null  int64
#  30  Bwd URG Flags      209368 non-null  int64
#  31  Fwd Header Len     209368 non-null  int64
#  32  Bwd Header Len     209368 non-null  int64
#  33  Fwd Pkts/s         209368 non-null  int64
#  34  Bwd Pkts/s         209368 non-null  int64
#  35  Pkt Len Max        209368 non-null  int64
#  36  Pkt Len Mean       209368 non-null  int64
#  37  Pkt Len Std        209368 non-null  int64
#  38  Pkt Len Var        209368 non-null  int64
#  39  RST Flag Cnt       209368 non-null  int64
#  40  PSH Flag Cnt       209368 non-null  int64
#  41  ACK Flag Cnt       209368 non-null  int64
#  42  ECE Flag Cnt       209368 non-null  int64
#  43  Down/Up Ratio      209368 non-null  int64
#  44  Pkt Size Avg       209368 non-null  int64
#  45  Fwd Seg Size Avg   209368 non-null  int64
#  46  Bwd Seg Size Avg   209368 non-null  int64
#  47  Subflow Fwd Pkts   209368 non-null  int64
#  48  Subflow Fwd Byts   209368 non-null  int64
#  49  Subflow Bwd Pkts   209368 non-null  int64
#  50  Subflow Bwd Byts   209368 non-null  int64
#  51  Init Fwd Win Byts  209368 non-null  int64
#  52  Init Bwd Win Byts  209368 non-null  int64
#  53  Fwd Act Data Pkts  209368 non-null  int64
#  54  Label              209368 non-null  int64
# dtypes: int64(55)
# memory usage: 87.9 MB

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
data = ['Train Data','Test Data']
Label = [837476,209368]
ax.pie(Label,labels=data,autopct='%1.2f%%')
plt.show()

# %%
traindata.groupby('Label')['Label'].count()
# Out:
# Label
# 0    288811
# 1    548665
# Name: Label, dtype: int64

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
data = ['Benign','DDoS HTTP Flood']
Label = [288811,548665]
ax.pie(Label,labels=data,autopct='%1.2f%%')
plt.show()

# %%
testdata.groupby('Label')['Label'].count()
# Out:
# Label
# 0     72021
# 1    137347
# Name: Label, dtype: int64

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
data = ['Benign','DDoS HTTP Flood']
Label = [72021,137347]
ax.pie(Label,labels=data,autopct='%1.2f%%')
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
data = ['Benign','DDoS HTTP Flood']
Label = [360833,686012]
ax.pie(Label,labels=data,autopct='%1.2f%%')
plt.show()

# %%
X = traindata.iloc[:, 0:53]
Y = traindata.iloc[:, 54]
C = testdata.iloc[:, 54]
T = testdata.iloc[:, 0:53]

# %%
scaler = Normalizer().fit(X)
trainX = scaler.transform(X)

# %%
scaler = Normalizer().fit(T)
testT = scaler.transform(T)

# %%
y_train = np.array(Y)
y_test = np.array(C)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
X_test = np.reshape(testT, (testT.shape[0], 1, testT.shape[1]))

# %%
print(X_train.shape)
# Out:
# (837476, 1, 53)

# %%
batch_size = 64

# %%
model = Sequential()
model.add(LSTM(16,input_dim=53, return_sequences=True,activation='tanh'))  # try using a GRU instead, for fun
model.add(Dropout(0.1))
model.add(LSTM(8, return_sequences=False, activation='tanh'))  # try using a GRU instead, for fun
model.add(Dropout(0.1))
model.add(Dense(1))
model.add(Activation('sigmoid'))
print(model.get_config())
# Out:
# {'name': 'sequential', 'layers': [{'class_name': 'InputLayer', 'config': {'batch_input_shape': (None, None, 53), 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'lstm_input'}}, {'class_name': 'LSTM', 'config': {'name': 'lstm', 'trainable': True, 'batch_input_shape': (None, None, 53), 'dtype': 'float32', 'return_sequences': True, 'return_state': False, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False, 'units': 16, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'recurrent_initializer': {'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'unit_forget_bias': True, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 2}}, {'class_name': 'Dropout', 'config': {'name': 'dropout', 'trainable': True, 'dtype': 'float32', 'rate': 0.1, 'noise_shape': None, 'seed': None}}, {'class_name': 'LSTM', 'config': {'name': 'lstm_1', 'trainable': True, 'dtype': 'float32', 'return_sequences': False, 'return_state': False, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False, 'units': 8, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'recurrent_initializer': {'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'unit_forget_bias': True, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 2}}, {'class_name': 'Dropout', 'config': {'name': 'dropout_1', 'trainable': True, 'dtype': 'float32', 'rate': 0.1, 'noise_shape': None, 'seed': None}}, {'class_name': 'Dense', 'config': {'name': 'dense', 'trainable': True, 'dtype': 'float32', 'units': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Activation', 'config': {'name': 'activation', 'trainable': True, 'dtype': 'float32', 'activation': 'sigmoid'}}]}

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 16)          4480
# _________________________________________________________________
# dropout (Dropout)            (None, None, 16)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# _________________________________________________________________
# activation (Activation)      (None, 1)                 0
# =================================================================
# Total params: 5,289
# Trainable params: 5,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
import keras
model.compile(loss='binary_crossentropy',optimizer=keras.optimizers.SGD(learning_rate=0.001),metrics=['accuracy'])
csv_logger = CSVLogger('training_set_iranalysis.csv',separator=',', append=False)
lstm_model = model.fit(X_train, y_train, batch_size=64, epochs=100, validation_data=(X_test, y_test),callbacks=[csv_logger])
model.save("kddresults/lstm/fullmodel/lstm_model.hdf5")
# Out:
# Epoch 1/100
# 13086/13086 [==============================] - 119s 7ms/step - loss: 0.6618 - accuracy: 0.6530 - val_loss: 0.6414 - val_accuracy: 0.6560
# Epoch 2/100
# 13086/13086 [==============================] - 87s 7ms/step - loss: 0.6409 - accuracy: 0.6556 - val_loss: 0.6374 - val_accuracy: 0.6560
# Epoch 3/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.6358 - accuracy: 0.6555 - val_loss: 0.6315 - val_accuracy: 0.6560
# Epoch 4/100
# 13086/13086 [==============================] - 89s 7ms/step - loss: 0.6278 - accuracy: 0.6552 - val_loss: 0.6204 - val_accuracy: 0.6560
# Epoch 5/100
# 13086/13086 [==============================] - 87s 7ms/step - loss: 0.6118 - accuracy: 0.6551 - val_loss: 0.5950 - val_accuracy: 0.6560
# Epoch 6/100
# 13086/13086 [==============================] - 88s 7ms/step - loss: 0.5741 - accuracy: 0.6559 - val_loss: 0.5327 - val_accuracy: 0.6560
# Epoch 7/100
# 13086/13086 [==============================] - 88s 7ms/step - loss: 0.4941 - accuracy: 0.7130 - val_loss: 0.4389 - val_accuracy: 0.7604
# Epoch 8/100
# 13086/13086 [==============================] - 87s 7ms/step - loss: 0.4076 - accuracy: 0.7980 - val_loss: 0.3799 - val_accuracy: 0.7973
# Epoch 9/100
# 13086/13086 [==============================] - 87s 7ms/step - loss: 0.3661 - accuracy: 0.8128 - val_loss: 0.3500 - val_accuracy: 0.8118
# Epoch 10/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.3444 - accuracy: 0.8208 - val_loss: 0.3289 - val_accuracy: 0.8202
# Epoch 11/100
# 13086/13086 [==============================] - 87s 7ms/step - loss: 0.3245 - accuracy: 0.8297 - val_loss: 0.3023 - val_accuracy: 0.8524
# Epoch 12/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.2853 - accuracy: 0.8638 - val_loss: 0.2635 - val_accuracy: 0.8565
# Epoch 13/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.2343 - accuracy: 0.9104 - val_loss: 0.2259 - val_accuracy: 0.8885
# Epoch 14/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.1852 - accuracy: 0.9375 - val_loss: 0.1839 - val_accuracy: 0.9208
# Epoch 15/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.1442 - accuracy: 0.9582 - val_loss: 0.1433 - val_accuracy: 0.9505
# Epoch 16/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.1123 - accuracy: 0.9710 - val_loss: 0.1090 - val_accuracy: 0.9608
# Epoch 17/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0886 - accuracy: 0.9785 - val_loss: 0.0834 - val_accuracy: 0.9735
# Epoch 18/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0709 - accuracy: 0.9836 - val_loss: 0.0655 - val_accuracy: 0.9813
# Epoch 19/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0584 - accuracy: 0.9870 - val_loss: 0.0539 - val_accuracy: 0.9841
# Epoch 20/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0490 - accuracy: 0.9898 - val_loss: 0.0459 - val_accuracy: 0.9863
# Epoch 21/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0424 - accuracy: 0.9921 - val_loss: 0.0397 - val_accuracy: 0.9882
# Epoch 22/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0368 - accuracy: 0.9939 - val_loss: 0.0360 - val_accuracy: 0.9890
# Epoch 23/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0329 - accuracy: 0.9943 - val_loss: 0.0326 - val_accuracy: 0.9900
# Epoch 24/100
# 13086/13086 [==============================] - 87s 7ms/step - loss: 0.0296 - accuracy: 0.9950 - val_loss: 0.0303 - val_accuracy: 0.9902
# Epoch 25/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0273 - accuracy: 0.9949 - val_loss: 0.0279 - val_accuracy: 0.9908
# Epoch 26/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0248 - accuracy: 0.9958 - val_loss: 0.0254 - val_accuracy: 0.9918
# Epoch 27/100
# 13086/13086 [==============================] - 87s 7ms/step - loss: 0.0227 - accuracy: 0.9965 - val_loss: 0.0229 - val_accuracy: 0.9930
# Epoch 28/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0210 - accuracy: 0.9970 - val_loss: 0.0212 - val_accuracy: 0.9938
# Epoch 29/100
# 13086/13086 [==============================] - 85s 6ms/step - loss: 0.0192 - accuracy: 0.9973 - val_loss: 0.0200 - val_accuracy: 0.9941
# Epoch 30/100
# 13086/13086 [==============================] - 85s 6ms/step - loss: 0.0184 - accuracy: 0.9972 - val_loss: 0.0185 - val_accuracy: 0.9959
# Epoch 31/100
# 13086/13086 [==============================] - 85s 6ms/step - loss: 0.0172 - accuracy: 0.9975 - val_loss: 0.0174 - val_accuracy: 0.9967
# Epoch 32/100
# 13086/13086 [==============================] - 85s 6ms/step - loss: 0.0161 - accuracy: 0.9975 - val_loss: 0.0167 - val_accuracy: 0.9966
# Epoch 33/100
# 13086/13086 [==============================] - 85s 6ms/step - loss: 0.0154 - accuracy: 0.9976 - val_loss: 0.0152 - val_accuracy: 0.9975
# Epoch 34/100
# 13086/13086 [==============================] - 85s 6ms/step - loss: 0.0150 - accuracy: 0.9976 - val_loss: 0.0148 - val_accuracy: 0.9974
# Epoch 35/100
# 13086/13086 [==============================] - 84s 6ms/step - loss: 0.0140 - accuracy: 0.9979 - val_loss: 0.0139 - val_accuracy: 0.9976
# Epoch 36/100
# 13086/13086 [==============================] - 85s 6ms/step - loss: 0.0137 - accuracy: 0.9977 - val_loss: 0.0130 - val_accuracy: 0.9977
# Epoch 37/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0132 - accuracy: 0.9979 - val_loss: 0.0124 - val_accuracy: 0.9977
# Epoch 38/100
# 13086/13086 [==============================] - 87s 7ms/step - loss: 0.0124 - accuracy: 0.9981 - val_loss: 0.0121 - val_accuracy: 0.9991
# Epoch 39/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0123 - accuracy: 0.9980 - val_loss: 0.0114 - val_accuracy: 0.9995
# Epoch 40/100
# 13086/13086 [==============================] - 88s 7ms/step - loss: 0.0114 - accuracy: 0.9982 - val_loss: 0.0111 - val_accuracy: 0.9995
# Epoch 41/100
# 13086/13086 [==============================] - 90s 7ms/step - loss: 0.0113 - accuracy: 0.9982 - val_loss: 0.0104 - val_accuracy: 0.9995
# Epoch 42/100
# 13086/13086 [==============================] - 90s 7ms/step - loss: 0.0109 - accuracy: 0.9983 - val_loss: 0.0102 - val_accuracy: 0.9995
# Epoch 43/100
# 13086/13086 [==============================] - 88s 7ms/step - loss: 0.0104 - accuracy: 0.9984 - val_loss: 0.0099 - val_accuracy: 0.9996
# Epoch 44/100
# 13086/13086 [==============================] - 88s 7ms/step - loss: 0.0105 - accuracy: 0.9985 - val_loss: 0.0094 - val_accuracy: 0.9995
# Epoch 45/100
# 13086/13086 [==============================] - 88s 7ms/step - loss: 0.0101 - accuracy: 0.9984 - val_loss: 0.0092 - val_accuracy: 0.9995
# Epoch 46/100
# 13086/13086 [==============================] - 88s 7ms/step - loss: 0.0098 - accuracy: 0.9985 - val_loss: 0.0091 - val_accuracy: 0.9996
# Epoch 47/100
# 13086/13086 [==============================] - 89s 7ms/step - loss: 0.0092 - accuracy: 0.9986 - val_loss: 0.0088 - val_accuracy: 0.9996
# Epoch 48/100
# 13086/13086 [==============================] - 88s 7ms/step - loss: 0.0091 - accuracy: 0.9987 - val_loss: 0.0083 - val_accuracy: 0.9995
# Epoch 49/100
# 13086/13086 [==============================] - 89s 7ms/step - loss: 0.0089 - accuracy: 0.9987 - val_loss: 0.0085 - val_accuracy: 0.9996
# Epoch 50/100
# 13086/13086 [==============================] - 88s 7ms/step - loss: 0.0087 - accuracy: 0.9986 - val_loss: 0.0079 - val_accuracy: 0.9995
# Epoch 51/100
# 13086/13086 [==============================] - 88s 7ms/step - loss: 0.0089 - accuracy: 0.9988 - val_loss: 0.0079 - val_accuracy: 0.9996
# Epoch 52/100
# 13086/13086 [==============================] - 89s 7ms/step - loss: 0.0084 - accuracy: 0.9989 - val_loss: 0.0077 - val_accuracy: 0.9996
# Epoch 53/100
# 13086/13086 [==============================] - 88s 7ms/step - loss: 0.0084 - accuracy: 0.9989 - val_loss: 0.0076 - val_accuracy: 0.9996
# Epoch 54/100
# 13086/13086 [==============================] - 89s 7ms/step - loss: 0.0080 - accuracy: 0.9989 - val_loss: 0.0072 - val_accuracy: 0.9995
# Epoch 55/100
# 13086/13086 [==============================] - 88s 7ms/step - loss: 0.0080 - accuracy: 0.9990 - val_loss: 0.0072 - val_accuracy: 0.9996
# Epoch 56/100
# 13086/13086 [==============================] - 88s 7ms/step - loss: 0.0077 - accuracy: 0.9990 - val_loss: 0.0070 - val_accuracy: 0.9996
# Epoch 57/100
# 13086/13086 [==============================] - 85s 7ms/step - loss: 0.0077 - accuracy: 0.9991 - val_loss: 0.0070 - val_accuracy: 0.9996
# Epoch 58/100
# 13086/13086 [==============================] - 85s 7ms/step - loss: 0.0076 - accuracy: 0.9991 - val_loss: 0.0067 - val_accuracy: 0.9996
# Epoch 59/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0073 - accuracy: 0.9991 - val_loss: 0.0066 - val_accuracy: 0.9995
# Epoch 60/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0072 - accuracy: 0.9991 - val_loss: 0.0064 - val_accuracy: 0.9995
# Epoch 61/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0069 - accuracy: 0.9992 - val_loss: 0.0064 - val_accuracy: 0.9996
# Epoch 62/100
# 13086/13086 [==============================] - 85s 7ms/step - loss: 0.0071 - accuracy: 0.9992 - val_loss: 0.0062 - val_accuracy: 0.9995
# Epoch 63/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0073 - accuracy: 0.9992 - val_loss: 0.0061 - val_accuracy: 0.9995
# Epoch 64/100
# 13086/13086 [==============================] - 88s 7ms/step - loss: 0.0068 - accuracy: 0.9992 - val_loss: 0.0061 - val_accuracy: 0.9995
# Epoch 65/100
# 13086/13086 [==============================] - 87s 7ms/step - loss: 0.0070 - accuracy: 0.9991 - val_loss: 0.0060 - val_accuracy: 0.9996
# Epoch 66/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0066 - accuracy: 0.9992 - val_loss: 0.0057 - val_accuracy: 0.9995
# Epoch 67/100
# 13086/13086 [==============================] - 86s 7ms/step - loss: 0.0064 - accuracy: 0.9993 - val_loss: 0.0059 - val_accuracy: 0.9996
# Epoch 68/100
# 13086/13086 [==============================] - 87s 7ms/step - loss: 0.0064 - accuracy: 0.9992 - val_loss: 0.0058 - val_accuracy: 0.9995
# Epoch 69/100
# 13086/13086 [==============================] - 91s 7ms/step - loss: 0.0064 - accuracy: 0.9993 - val_loss: 0.0057 - val_accuracy: 0.9996
# Epoch 70/100
# 13086/13086 [==============================] - 90s 7ms/step - loss: 0.0064 - accuracy: 0.9992 - val_loss: 0.0056 - val_accuracy: 0.9996
# Epoch 71/100
# 13086/13086 [==============================] - 90s 7ms/step - loss: 0.0064 - accuracy: 0.9992 - val_loss: 0.0055 - val_accuracy: 0.9996
# Epoch 72/100
# 13086/13086 [==============================] - 91s 7ms/step - loss: 0.0061 - accuracy: 0.9992 - val_loss: 0.0055 - val_accuracy: 0.9996
# Epoch 73/100
# 13086/13086 [==============================] - 91s 7ms/step - loss: 0.0062 - accuracy: 0.9993 - val_loss: 0.0055 - val_accuracy: 0.9996
# Epoch 74/100
# 13086/13086 [==============================] - 91s 7ms/step - loss: 0.0061 - accuracy: 0.9992 - val_loss: 0.0055 - val_accuracy: 0.9996
# Epoch 75/100
# 13086/13086 [==============================] - 91s 7ms/step - loss: 0.0059 - accuracy: 0.9992 - val_loss: 0.0052 - val_accuracy: 0.9996
# Epoch 76/100
# 13086/13086 [==============================] - 91s 7ms/step - loss: 0.0059 - accuracy: 0.9992 - val_loss: 0.0053 - val_accuracy: 0.9996
# Epoch 77/100
# 13086/13086 [==============================] - 91s 7ms/step - loss: 0.0059 - accuracy: 0.9992 - val_loss: 0.0052 - val_accuracy: 0.9996
# Epoch 78/100
# 13086/13086 [==============================] - 90s 7ms/step - loss: 0.0057 - accuracy: 0.9993 - val_loss: 0.0051 - val_accuracy: 0.9996
# Epoch 79/100
# 13086/13086 [==============================] - 91s 7ms/step - loss: 0.0056 - accuracy: 0.9993 - val_loss: 0.0050 - val_accuracy: 0.9996
# Epoch 80/100
# 13086/13086 [==============================] - 92s 7ms/step - loss: 0.0055 - accuracy: 0.9993 - val_loss: 0.0049 - val_accuracy: 0.9996
# Epoch 81/100
# 13086/13086 [==============================] - 91s 7ms/step - loss: 0.0055 - accuracy: 0.9993 - val_loss: 0.0049 - val_accuracy: 0.9996
# Epoch 82/100
# 13086/13086 [==============================] - 90s 7ms/step - loss: 0.0054 - accuracy: 0.9993 - val_loss: 0.0049 - val_accuracy: 0.9996
# Epoch 83/100
# 13086/13086 [==============================] - 92s 7ms/step - loss: 0.0054 - accuracy: 0.9994 - val_loss: 0.0049 - val_accuracy: 0.9996
# Epoch 84/100
# 13086/13086 [==============================] - 91s 7ms/step - loss: 0.0056 - accuracy: 0.9993 - val_loss: 0.0047 - val_accuracy: 0.9995
# Epoch 85/100
# 13086/13086 [==============================] - 90s 7ms/step - loss: 0.0053 - accuracy: 0.9993 - val_loss: 0.0049 - val_accuracy: 0.9996
# Epoch 86/100
# 13086/13086 [==============================] - 90s 7ms/step - loss: 0.0054 - accuracy: 0.9993 - val_loss: 0.0048 - val_accuracy: 0.9996
# Epoch 87/100
# 13086/13086 [==============================] - 90s 7ms/step - loss: 0.0055 - accuracy: 0.9993 - val_loss: 0.0048 - val_accuracy: 0.9996
# Epoch 88/100
# 13086/13086 [==============================] - 90s 7ms/step - loss: 0.0055 - accuracy: 0.9993 - val_loss: 0.0046 - val_accuracy: 0.9995
# Epoch 89/100
# 13086/13086 [==============================] - 90s 7ms/step - loss: 0.0050 - accuracy: 0.9993 - val_loss: 0.0047 - val_accuracy: 0.9996
# Epoch 90/100
# 13086/13086 [==============================] - 90s 7ms/step - loss: 0.0051 - accuracy: 0.9993 - val_loss: 0.0046 - val_accuracy: 0.9996
# Epoch 91/100
# 13086/13086 [==============================] - 90s 7ms/step - loss: 0.0052 - accuracy: 0.9994 - val_loss: 0.0046 - val_accuracy: 0.9996
# Epoch 92/100
# 13086/13086 [==============================] - 89s 7ms/step - loss: 0.0052 - accuracy: 0.9993 - val_loss: 0.0046 - val_accuracy: 0.9996
# Epoch 93/100
# 13086/13086 [==============================] - 90s 7ms/step - loss: 0.0053 - accuracy: 0.9994 - val_loss: 0.0045 - val_accuracy: 0.9996
# Epoch 94/100
# 13086/13086 [==============================] - 89s 7ms/step - loss: 0.0052 - accuracy: 0.9993 - val_loss: 0.0046 - val_accuracy: 0.9996
# Epoch 95/100
# 13086/13086 [==============================] - 89s 7ms/step - loss: 0.0050 - accuracy: 0.9993 - val_loss: 0.0044 - val_accuracy: 0.9996
# Epoch 96/100
# 13086/13086 [==============================] - 91s 7ms/step - loss: 0.0050 - accuracy: 0.9993 - val_loss: 0.0044 - val_accuracy: 0.9996
# Epoch 97/100
# 13086/13086 [==============================] - 89s 7ms/step - loss: 0.0048 - accuracy: 0.9994 - val_loss: 0.0044 - val_accuracy: 0.9995
# Epoch 98/100
# 13086/13086 [==============================] - 90s 7ms/step - loss: 0.0048 - accuracy: 0.9993 - val_loss: 0.0042 - val_accuracy: 0.9995
# Epoch 99/100
# 13086/13086 [==============================] - 94s 7ms/step - loss: 0.0049 - accuracy: 0.9993 - val_loss: 0.0043 - val_accuracy: 0.9996
# Epoch 100/100
# 13086/13086 [==============================] - 94s 7ms/step - loss: 0.0050 - accuracy: 0.9994 - val_loss: 0.0043 - val_accuracy: 0.9995

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("\nLoss: %4f, Accuracy: %.4f%%" % (loss, accuracy*100))
lstm_predict = model.predict_classes(X_test)
# Out:
# 6543/6543 [==============================] - 22s 3ms/step - loss: 0.0043 - accuracy: 0.9995
#
# Loss: 0.004273, Accuracy: 99.9532%
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
plt.plot(lstm_model.history['accuracy'])
plt.plot(lstm_model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('Akurasi')
plt.xlabel('Epoch')
plt.legend(['Data latih', 'Data uji'], loc='lower right')
plt.show()

# %%
plt.plot(lstm_model.history['loss'])
plt.plot(lstm_model.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Data latih', 'Data uji'], loc='upper right')
plt.show()

# %%
cm = confusion_matrix(y_test, lstm_predict)
print(cm)
tp = cm[0,0]
tn = cm[1,1]
fp = cm[0,1]
fn = cm[1,0]
# Out:
# [[ 71926     95]
#  [     3 137344]]

# %%
precision = tp / ( tp + fp)
recall = tp/(tp+fn)
f1=(2*precision*recall)/ (precision+recall)
akurasi = (tp+tn)/(tp+tn+fp+fn)
Sensitivity = tp/(tp + fn)

# %%
print ("precesion : ",precision)
print("recall : ",recall)
print ("F1 : ",f1)
print("sensitivity : ",Sensitivity )
print("akurasi : ",akurasi)
# Out:
# precesion :  0.9986809402813068
# recall :  0.999958292204813
# F1 :  0.9993192080583535
# sensitivity :  0.999958292204813
# akurasi :  0.9995319246494211

# %%
import keras
import seaborn as sns
from sklearn.metrics import roc_curve, auc

fpr_keras,tpr_keras, threshold =roc_curve(y_test, lstm_predict)
auc=auc(fpr_keras,tpr_keras)

plt.figure(1)
plt.plot([0,1],[0,1],'k--',color='yellow')
plt.plot(fpr_keras, tpr_keras, label="ROC CURVE {0:.4f}".format(auc))
plt.xlabel('false positive rate (spesitivity)')
plt.ylabel('true positive rate(sensitivity)')
plt.title('ROC CURVE')
plt.legend(loc='best')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from sklearn.metrics import average_precision_score
average_precision = average_precision_score(y_test, lstm_predict)

print('Average precision-recall score: {0:0.8f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.99930129

# %%
from inspect import signature
from sklearn.metrics import precision_recall_curve
precision, recall, threshold = precision_recall_curve(y_test, lstm_predict)
average_precision = average_precision_score(y_test, lstm_predict)
step_kwargs = ({'step': 'post'} if 'step' in signature(plt.fill_between).parameters else {})
plt.step(recall, precision, color='r', alpha=0.5, where='post')
plt.fill_between(recall, precision, alpha=0.5, color='w', **step_kwargs)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.5000, 1.0000])
plt.xlim([0.9980, 1.0000])
plt.title('2-class Precision-Recall curve: AP={0:0.8f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, '2-class Precision-Recall curve: AP=0.99930129')

# %%
lstm_predict
# Out:
# array([[1],
#        [0],
#        [0],
#        ...,
#        [1],
#        [1],
#        [0]], dtype=int32)

# %%
import pandas as pd
import numpy as np
lstm_predict.shape
# Out:
# (209368, 1)

# %%
type(lstm_predict)
# Out:
# numpy.ndarray

# %%
dataset = pd.DataFrame()
dataset['lstm_predict'] = lstm_predict.tolist()

# %%
dataset.head()
# Out:
#   lstm_predict
# 0          [1]
# 1          [0]
# 2          [0]
# 3          [0]
# 4          [1]

# %%
hasil = pd.concat([testdata,dataset], axis=1)

# %%
hasil.to_csv(r'validasi_80_20.csv')

# %%
hasil = pd.read_csv('validasi_80_20.csv')

# %%
data = hasil.replace(to_replace = ["[1]"],value = 1)
data = data.replace(to_replace = ["[0]"],value = 0)

# %%
data.head(20)
# Out:
#     Unnamed: 0  Dst Port  Tot Fwd Pkts  ...  Fwd Act Data Pkts  Label  lstm_predict
# 0            0         3             2  ...                  1      1             1
# 1            1       278             4  ...                  1      0             0
# 2            2      8100             4  ...                  1      0             0
# 3            3       424             4  ...                  1      0             0
# 4            4         3             2  ...                  1      1             1
# 5            5       859             4  ...                  1      0             0
# 6            6     15436             4  ...                  1      0             0
# 7            7         3             2  ...                  1      1             1
# 8            8      4875             4  ...                  1      0             0
# 9            9         3             2  ...                  1      1             1
# 10          10         3             1  ...                  0      1             1
# 11          11         3             1  ...                  0      1             1
# 12          12         3             1  ...                  0      1             1
# 13          13         3             1  ...                  0      1             1
# 14          14         3             2  ...                  1      1             1
# 15          15         3             1  ...                  0      1             1
# 16          16         3             2  ...                  1      1             1
# 17          17     15542             4  ...                  1      0             0
# 18          18     11416             4  ...                  1      0             0
# 19          19         3             1  ...                  0      1             1
#
# [20 rows x 57 columns]

# %%
data_attack = data[data["Label"]==1]
data_normal = data[data["Label"]==0]

# %%
attack_error = data_attack[data_attack.loc[:,"Label"] != data_attack.loc[:,"lstm_predict"]]
normal_error = data_normal[data_normal.loc[:,"Label"] != data_normal.loc[:,"lstm_predict"]]

# %%
attack_error
# Out:
#         Unnamed: 0  Dst Port  ...  Label  lstm_predict
# 46372        46372         3  ...      1             0
# 161719      161719         3  ...      1             0
# 168201      168201         3  ...      1             0
#
# [3 rows x 57 columns]

# %%
normal_error.head(20)
# Out:
#        Unnamed: 0  Dst Port  ...  Label  lstm_predict
# 4536         4536       106  ...      0             1
# 4723         4723       636  ...      0             1
# 11487       11487       508  ...      0             1
# 12646       12646        18  ...      0             1
# 12980       12980         5  ...      0             1
# 17423       17423         1  ...      0             1
# 17730       17730         7  ...      0             1
# 18706       18706         2  ...      0             1
# 21028       21028         1  ...      0             1
# 23113       23113        23  ...      0             1
# 23741       23741       366  ...      0             1
# 26417       26417       425  ...      0             1
# 28776       28776       483  ...      0             1
# 30221       30221        17  ...      0             1
# 31504       31504         4  ...      0             1
# 37158       37158       484  ...      0             1
# 42214       42214         6  ...      0             1
# 42661       42661        20  ...      0             1
# 43517       43517       789  ...      0             1
# 45533       45533       127  ...      0             1
#
# [20 rows x 57 columns]
