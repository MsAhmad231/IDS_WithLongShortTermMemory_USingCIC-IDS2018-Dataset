# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive

# copy the .zip file into the root directory of cloud VM
# !cp /content/gdrive/MyDrive/dataset.zip ../

# unzip the zip file and its contents should now be in /darknet/data/obj
# !unzip ../dataset.zip
# Out:
# 'Arsitektur ANN.png'
# 'Arsitektur LSTM.drawio'
#  Classroom
# 'Colab Notebooks'
#  dataset
#  Dataset_mutia.csv
#  dataset.zip
# 'DDoS_LSTM_Model_53 Fitur.ipynb'
#  DDoS_LSTM_Model_69_Fitur_50_50.ipynb
#  hasil.zip
# 'koding dan hasil'
# 'koding ta2'
# 'LSTM TA2.drawio'
# 'My Drive'
# 'Salinan DDoS_LSTM_Model_69_Fitur_50_50.ipynb'
# 'Untitled Diagram (1).drawio'
# 'Untitled Diagram (2).drawio'
# 'Untitled Diagram.drawio'
# Archive:  ../dataset.zip
#    creating: dataset/
#   inflating: dataset/testdata_10.csv
#   inflating: dataset/testdata_20.csv
#   inflating: dataset/testdata_30.csv
#   inflating: dataset/testdata_40.csv
#   inflating: dataset/testdata_50.csv
#   inflating: dataset/traindata_50.csv
#   inflating: dataset/traindata_60.csv
#   inflating: dataset/traindata_70.csv
#   inflating: dataset/traindata_80.csv
#   inflating: dataset/traindata_90.csv

# %%
from __future__ import print_function
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
np.random.seed(1337)  # for reproducibility
from keras.preprocessing import sequence
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Embedding
from keras.layers import LSTM, SimpleRNN, GRU
from keras.datasets import imdb
from keras.utils.np_utils import to_categorical
from sklearn.metrics import (precision_score, recall_score,f1_score, accuracy_score,mean_squared_error,mean_absolute_error)
from sklearn import metrics
from sklearn.preprocessing import Normalizer
import h5py
from keras import callbacks
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

# %%
traindata = pd.read_csv('dataset/traindata_70.csv')
testdata = pd.read_csv('dataset/testdata_30.csv')

# %%
traindata.drop(['Unnamed: 0','Timestamp'], axis = 1, inplace=True)
testdata.drop(['Unnamed: 0','Timestamp'], axis = 1, inplace=True)

# %%
traindata = traindata.replace(to_replace = ["DDOS attack-HOIC"],value = 1)
traindata = traindata.replace(to_replace = ["Benign"],value = 0)
testdata = testdata.replace(to_replace = ["DDOS attack-HOIC"],value = 1)
testdata = testdata.replace(to_replace = ["Benign"],value = 0)

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor1 = traindata.corr()
sns.heatmap(cor1, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
a = abs(cor1['Label'])
result = a[a > 0.1]
result
# Out:
# Dst Port             0.990327
# Tot Fwd Pkts         0.931274
# Tot Bwd Pkts         0.332074
# TotLen Fwd Pkts      0.963313
# TotLen Bwd Pkts      0.108894
# Fwd Pkt Len Max      0.964741
# Fwd Pkt Len Mean     0.907524
# Fwd Pkt Len Std      0.942513
# Bwd Pkt Len Max      0.108762
# Bwd Pkt Len Mean     0.477399
# Bwd Pkt Len Std      0.278491
# Flow Byts/s          0.687197
# Flow Pkts/s          0.289231
# Bwd IAT Min          0.123228
# Fwd Header Len       0.948039
# Bwd Header Len       0.255615
# Fwd Pkts/s           0.216406
# Bwd Pkts/s           0.436455
# Pkt Len Max          0.718480
# Pkt Len Mean         0.718223
# Pkt Len Std          0.717691
# Pkt Len Var          0.717608
# RST Flag Cnt         0.717462
# PSH Flag Cnt         0.718149
# ACK Flag Cnt         0.723393
# ECE Flag Cnt         0.717462
# Down/Up Ratio        0.311696
# Pkt Size Avg         0.717878
# Fwd Seg Size Avg     0.907524
# Bwd Seg Size Avg     0.477399
# Subflow Fwd Pkts     0.931274
# Subflow Fwd Byts     0.963313
# Subflow Bwd Pkts     0.332074
# Subflow Bwd Byts     0.108894
# Init Fwd Win Byts    0.705842
# Init Bwd Win Byts    0.995113
# Fwd Act Data Pkts    0.544063
# Label                1.000000
# Name: Label, dtype: float64

# %%
traindata.drop(['Protocol','Flow Byts/s','Flow Pkts/s','Pkt Len Min','Fwd Byts/b Avg','Fwd Pkts/b Avg','Fwd Blk Rate Avg','Bwd Byts/b Avg','Bwd Pkts/b Avg','Bwd Blk Rate Avg','Fwd Seg Size Min','Active Mean','Active Std','Active Max','Active Min','Idle Mean','Idle Std','Idle Max','Idle Min','FIN Flag Cnt','SYN Flag Cnt','URG Flag Cnt','CWE Flag Count','Flow Duration'], axis = 1, inplace=True)
testdata.drop(['Protocol','Flow Byts/s','Flow Pkts/s','Pkt Len Min','Fwd Byts/b Avg','Fwd Pkts/b Avg','Fwd Blk Rate Avg','Bwd Byts/b Avg','Bwd Pkts/b Avg','Bwd Blk Rate Avg','Fwd Seg Size Min','Active Mean','Active Std','Active Max','Active Min','Idle Mean','Idle Std','Idle Max','Idle Min','FIN Flag Cnt','SYN Flag Cnt','URG Flag Cnt','CWE Flag Count','Flow Duration'], axis = 1, inplace=True)

# %%
enc = LabelEncoder()
traindata = traindata.apply(enc.fit_transform)
testdata = testdata.apply(enc.fit_transform)

# %%
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732791 entries, 0 to 732790
# Data columns (total 55 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Dst Port           732791 non-null  int64
#  1   Tot Fwd Pkts       732791 non-null  int64
#  2   Tot Bwd Pkts       732791 non-null  int64
#  3   TotLen Fwd Pkts    732791 non-null  int64
#  4   TotLen Bwd Pkts    732791 non-null  int64
#  5   Fwd Pkt Len Max    732791 non-null  int64
#  6   Fwd Pkt Len Min    732791 non-null  int64
#  7   Fwd Pkt Len Mean   732791 non-null  int64
#  8   Fwd Pkt Len Std    732791 non-null  int64
#  9   Bwd Pkt Len Max    732791 non-null  int64
#  10  Bwd Pkt Len Min    732791 non-null  int64
#  11  Bwd Pkt Len Mean   732791 non-null  int64
#  12  Bwd Pkt Len Std    732791 non-null  int64
#  13  Flow IAT Mean      732791 non-null  int64
#  14  Flow IAT Std       732791 non-null  int64
#  15  Flow IAT Max       732791 non-null  int64
#  16  Flow IAT Min       732791 non-null  int64
#  17  Fwd IAT Tot        732791 non-null  int64
#  18  Fwd IAT Mean       732791 non-null  int64
#  19  Fwd IAT Std        732791 non-null  int64
#  20  Fwd IAT Max        732791 non-null  int64
#  21  Fwd IAT Min        732791 non-null  int64
#  22  Bwd IAT Tot        732791 non-null  int64
#  23  Bwd IAT Mean       732791 non-null  int64
#  24  Bwd IAT Std        732791 non-null  int64
#  25  Bwd IAT Max        732791 non-null  int64
#  26  Bwd IAT Min        732791 non-null  int64
#  27  Fwd PSH Flags      732791 non-null  int64
#  28  Bwd PSH Flags      732791 non-null  int64
#  29  Fwd URG Flags      732791 non-null  int64
#  30  Bwd URG Flags      732791 non-null  int64
#  31  Fwd Header Len     732791 non-null  int64
#  32  Bwd Header Len     732791 non-null  int64
#  33  Fwd Pkts/s         732791 non-null  int64
#  34  Bwd Pkts/s         732791 non-null  int64
#  35  Pkt Len Max        732791 non-null  int64
#  36  Pkt Len Mean       732791 non-null  int64
#  37  Pkt Len Std        732791 non-null  int64
#  38  Pkt Len Var        732791 non-null  int64
#  39  RST Flag Cnt       732791 non-null  int64
#  40  PSH Flag Cnt       732791 non-null  int64
#  41  ACK Flag Cnt       732791 non-null  int64
#  42  ECE Flag Cnt       732791 non-null  int64
#  43  Down/Up Ratio      732791 non-null  int64
#  44  Pkt Size Avg       732791 non-null  int64
#  45  Fwd Seg Size Avg   732791 non-null  int64
#  46  Bwd Seg Size Avg   732791 non-null  int64
#  47  Subflow Fwd Pkts   732791 non-null  int64
#  48  Subflow Fwd Byts   732791 non-null  int64
#  49  Subflow Bwd Pkts   732791 non-null  int64
#  50  Subflow Bwd Byts   732791 non-null  int64
#  51  Init Fwd Win Byts  732791 non-null  int64
#  52  Init Bwd Win Byts  732791 non-null  int64
#  53  Fwd Act Data Pkts  732791 non-null  int64
#  54  Label              732791 non-null  int64
# dtypes: int64(55)
# memory usage: 307.5 MB

# %%
testdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314053 entries, 0 to 314052
# Data columns (total 55 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Dst Port           314053 non-null  int64
#  1   Tot Fwd Pkts       314053 non-null  int64
#  2   Tot Bwd Pkts       314053 non-null  int64
#  3   TotLen Fwd Pkts    314053 non-null  int64
#  4   TotLen Bwd Pkts    314053 non-null  int64
#  5   Fwd Pkt Len Max    314053 non-null  int64
#  6   Fwd Pkt Len Min    314053 non-null  int64
#  7   Fwd Pkt Len Mean   314053 non-null  int64
#  8   Fwd Pkt Len Std    314053 non-null  int64
#  9   Bwd Pkt Len Max    314053 non-null  int64
#  10  Bwd Pkt Len Min    314053 non-null  int64
#  11  Bwd Pkt Len Mean   314053 non-null  int64
#  12  Bwd Pkt Len Std    314053 non-null  int64
#  13  Flow IAT Mean      314053 non-null  int64
#  14  Flow IAT Std       314053 non-null  int64
#  15  Flow IAT Max       314053 non-null  int64
#  16  Flow IAT Min       314053 non-null  int64
#  17  Fwd IAT Tot        314053 non-null  int64
#  18  Fwd IAT Mean       314053 non-null  int64
#  19  Fwd IAT Std        314053 non-null  int64
#  20  Fwd IAT Max        314053 non-null  int64
#  21  Fwd IAT Min        314053 non-null  int64
#  22  Bwd IAT Tot        314053 non-null  int64
#  23  Bwd IAT Mean       314053 non-null  int64
#  24  Bwd IAT Std        314053 non-null  int64
#  25  Bwd IAT Max        314053 non-null  int64
#  26  Bwd IAT Min        314053 non-null  int64
#  27  Fwd PSH Flags      314053 non-null  int64
#  28  Bwd PSH Flags      314053 non-null  int64
#  29  Fwd URG Flags      314053 non-null  int64
#  30  Bwd URG Flags      314053 non-null  int64
#  31  Fwd Header Len     314053 non-null  int64
#  32  Bwd Header Len     314053 non-null  int64
#  33  Fwd Pkts/s         314053 non-null  int64
#  34  Bwd Pkts/s         314053 non-null  int64
#  35  Pkt Len Max        314053 non-null  int64
#  36  Pkt Len Mean       314053 non-null  int64
#  37  Pkt Len Std        314053 non-null  int64
#  38  Pkt Len Var        314053 non-null  int64
#  39  RST Flag Cnt       314053 non-null  int64
#  40  PSH Flag Cnt       314053 non-null  int64
#  41  ACK Flag Cnt       314053 non-null  int64
#  42  ECE Flag Cnt       314053 non-null  int64
#  43  Down/Up Ratio      314053 non-null  int64
#  44  Pkt Size Avg       314053 non-null  int64
#  45  Fwd Seg Size Avg   314053 non-null  int64
#  46  Bwd Seg Size Avg   314053 non-null  int64
#  47  Subflow Fwd Pkts   314053 non-null  int64
#  48  Subflow Fwd Byts   314053 non-null  int64
#  49  Subflow Bwd Pkts   314053 non-null  int64
#  50  Subflow Bwd Byts   314053 non-null  int64
#  51  Init Fwd Win Byts  314053 non-null  int64
#  52  Init Bwd Win Byts  314053 non-null  int64
#  53  Fwd Act Data Pkts  314053 non-null  int64
#  54  Label              314053 non-null  int64
# dtypes: int64(55)
# memory usage: 131.8 MB

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
data = ['Train Data','Test Data']
Label = [732791,314054]
ax.pie(Label,labels=data,autopct='%1.2f%%')
plt.show()

# %%
traindata.groupby('Label')['Label'].count()
# Out:
# Label
# 0    252973
# 1    479818
# Name: Label, dtype: int64

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
data = ['Benign','DDoS HTTP Flood']
Label = [253384,480618]
ax.pie(Label,labels=data,autopct='%1.2f%%')
plt.show()

# %%
testdata.groupby('Label')['Label'].count()
# Out:
# Label
# 0    107860
# 1    206193
# Name: Label, dtype: int64

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
data = ['Benign','DDoS HTTP Flood']
Label = [107449,205393]
ax.pie(Label,labels=data,autopct='%1.2f%%')
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
data = ['Benign','DDoS HTTP Flood']
Label = [360833,686012]
ax.pie(Label,labels=data,autopct='%1.2f%%')
plt.show()

# %%
X = traindata.iloc[:, 0:53]
Y = traindata.iloc[:, 54]
C = testdata.iloc[:, 54]
T = testdata.iloc[:, 0:53]

# %%
scaler = Normalizer().fit(X)
trainX = scaler.transform(X)

# %%
scaler = Normalizer().fit(T)
testT = scaler.transform(T)

# %%
y_train = np.array(Y)
y_test = np.array(C)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
X_test = np.reshape(testT, (testT.shape[0], 1, testT.shape[1]))

# %%
print(X_train.shape)
# Out:
# (732791, 1, 53)

# %%
batch_size = 64

# %%
model = Sequential()
model.add(LSTM(16,input_dim=53, return_sequences=True,activation='tanh'))  # try using a GRU instead, for fun
model.add(Dropout(0.1))
model.add(LSTM(8, return_sequences=False, activation='tanh'))  # try using a GRU instead, for fun
model.add(Dropout(0.1))
model.add(Dense(1))
model.add(Activation('sigmoid'))
print(model.get_config())
# Out:
# {'name': 'sequential', 'layers': [{'class_name': 'InputLayer', 'config': {'batch_input_shape': (None, None, 53), 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'lstm_input'}}, {'class_name': 'LSTM', 'config': {'name': 'lstm', 'trainable': True, 'batch_input_shape': (None, None, 53), 'dtype': 'float32', 'return_sequences': True, 'return_state': False, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False, 'units': 16, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'recurrent_initializer': {'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'unit_forget_bias': True, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 2}}, {'class_name': 'Dropout', 'config': {'name': 'dropout', 'trainable': True, 'dtype': 'float32', 'rate': 0.1, 'noise_shape': None, 'seed': None}}, {'class_name': 'LSTM', 'config': {'name': 'lstm_1', 'trainable': True, 'dtype': 'float32', 'return_sequences': False, 'return_state': False, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False, 'units': 8, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'recurrent_initializer': {'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'unit_forget_bias': True, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 2}}, {'class_name': 'Dropout', 'config': {'name': 'dropout_1', 'trainable': True, 'dtype': 'float32', 'rate': 0.1, 'noise_shape': None, 'seed': None}}, {'class_name': 'Dense', 'config': {'name': 'dense', 'trainable': True, 'dtype': 'float32', 'units': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Activation', 'config': {'name': 'activation', 'trainable': True, 'dtype': 'float32', 'activation': 'sigmoid'}}]}

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 16)          4480
# _________________________________________________________________
# dropout (Dropout)            (None, None, 16)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# _________________________________________________________________
# activation (Activation)      (None, 1)                 0
# =================================================================
# Total params: 5,289
# Trainable params: 5,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
import keras
model.compile(loss='binary_crossentropy',optimizer=keras.optimizers.SGD(learning_rate=0.001),metrics=['accuracy'])
csv_logger = CSVLogger('training_set_iranalysis.csv',separator=',', append=False)
lstm_model = model.fit(X_train, y_train, batch_size=64, epochs=100, validation_data=(X_test, y_test),callbacks=[csv_logger])
model.save("kddresults/lstm/fullmodel/lstm_model.hdf5")
# Out:
# Epoch 1/100
# 11450/11450 [==============================] - 81s 5ms/step - loss: 0.6636 - accuracy: 0.6539 - val_loss: 0.6430 - val_accuracy: 0.6566
# Epoch 2/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.6438 - accuracy: 0.6544 - val_loss: 0.6414 - val_accuracy: 0.6566
# Epoch 3/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.6421 - accuracy: 0.6545 - val_loss: 0.6397 - val_accuracy: 0.6566
# Epoch 4/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.6400 - accuracy: 0.6548 - val_loss: 0.6375 - val_accuracy: 0.6566
# Epoch 5/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.6367 - accuracy: 0.6558 - val_loss: 0.6341 - val_accuracy: 0.6566
# Epoch 6/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.6334 - accuracy: 0.6544 - val_loss: 0.6286 - val_accuracy: 0.6566
# Epoch 7/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.6258 - accuracy: 0.6554 - val_loss: 0.6186 - val_accuracy: 0.6566
# Epoch 8/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.6130 - accuracy: 0.6552 - val_loss: 0.5985 - val_accuracy: 0.6566
# Epoch 9/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.5871 - accuracy: 0.6544 - val_loss: 0.5555 - val_accuracy: 0.6566
# Epoch 10/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.5330 - accuracy: 0.6636 - val_loss: 0.4801 - val_accuracy: 0.6949
# Epoch 11/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.4544 - accuracy: 0.7629 - val_loss: 0.4100 - val_accuracy: 0.7864
# Epoch 12/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.3962 - accuracy: 0.7995 - val_loss: 0.3705 - val_accuracy: 0.8068
# Epoch 13/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.3659 - accuracy: 0.8125 - val_loss: 0.3460 - val_accuracy: 0.8151
# Epoch 14/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.3455 - accuracy: 0.8193 - val_loss: 0.3181 - val_accuracy: 0.8305
# Epoch 15/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.3091 - accuracy: 0.8474 - val_loss: 0.2690 - val_accuracy: 0.8960
# Epoch 16/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.2563 - accuracy: 0.9004 - val_loss: 0.2271 - val_accuracy: 0.9080
# Epoch 17/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.2108 - accuracy: 0.9209 - val_loss: 0.1865 - val_accuracy: 0.9341
# Epoch 18/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.1679 - accuracy: 0.9466 - val_loss: 0.1475 - val_accuracy: 0.9532
# Epoch 19/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.1337 - accuracy: 0.9642 - val_loss: 0.1147 - val_accuracy: 0.9669
# Epoch 20/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.1066 - accuracy: 0.9747 - val_loss: 0.0895 - val_accuracy: 0.9767
# Epoch 21/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0863 - accuracy: 0.9811 - val_loss: 0.0709 - val_accuracy: 0.9817
# Epoch 22/100
# 11450/11450 [==============================] - 56s 5ms/step - loss: 0.0711 - accuracy: 0.9853 - val_loss: 0.0574 - val_accuracy: 0.9853
# Epoch 23/100
# 11450/11450 [==============================] - 56s 5ms/step - loss: 0.0604 - accuracy: 0.9881 - val_loss: 0.0484 - val_accuracy: 0.9873
# Epoch 24/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0519 - accuracy: 0.9904 - val_loss: 0.0410 - val_accuracy: 0.9898
# Epoch 25/100
# 11450/11450 [==============================] - 56s 5ms/step - loss: 0.0461 - accuracy: 0.9922 - val_loss: 0.0361 - val_accuracy: 0.9910
# Epoch 26/100
# 11450/11450 [==============================] - 56s 5ms/step - loss: 0.0409 - accuracy: 0.9935 - val_loss: 0.0326 - val_accuracy: 0.9915
# Epoch 27/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0366 - accuracy: 0.9944 - val_loss: 0.0295 - val_accuracy: 0.9923
# Epoch 28/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0331 - accuracy: 0.9945 - val_loss: 0.0267 - val_accuracy: 0.9931
# Epoch 29/100
# 11450/11450 [==============================] - 56s 5ms/step - loss: 0.0302 - accuracy: 0.9949 - val_loss: 0.0242 - val_accuracy: 0.9940
# Epoch 30/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0280 - accuracy: 0.9952 - val_loss: 0.0217 - val_accuracy: 0.9962
# Epoch 31/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0258 - accuracy: 0.9955 - val_loss: 0.0200 - val_accuracy: 0.9971
# Epoch 32/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0240 - accuracy: 0.9956 - val_loss: 0.0180 - val_accuracy: 0.9977
# Epoch 33/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0223 - accuracy: 0.9968 - val_loss: 0.0166 - val_accuracy: 0.9978
# Epoch 34/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0208 - accuracy: 0.9971 - val_loss: 0.0152 - val_accuracy: 0.9978
# Epoch 35/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0194 - accuracy: 0.9974 - val_loss: 0.0141 - val_accuracy: 0.9978
# Epoch 36/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0183 - accuracy: 0.9974 - val_loss: 0.0132 - val_accuracy: 0.9978
# Epoch 37/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0177 - accuracy: 0.9974 - val_loss: 0.0124 - val_accuracy: 0.9978
# Epoch 38/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0167 - accuracy: 0.9977 - val_loss: 0.0115 - val_accuracy: 0.9978
# Epoch 39/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0160 - accuracy: 0.9977 - val_loss: 0.0109 - val_accuracy: 0.9996
# Epoch 40/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0152 - accuracy: 0.9979 - val_loss: 0.0104 - val_accuracy: 0.9996
# Epoch 41/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0144 - accuracy: 0.9980 - val_loss: 0.0096 - val_accuracy: 0.9996
# Epoch 42/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0143 - accuracy: 0.9980 - val_loss: 0.0093 - val_accuracy: 0.9996
# Epoch 43/100
# 11450/11450 [==============================] - 56s 5ms/step - loss: 0.0136 - accuracy: 0.9980 - val_loss: 0.0088 - val_accuracy: 0.9996
# Epoch 44/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0134 - accuracy: 0.9982 - val_loss: 0.0085 - val_accuracy: 0.9996
# Epoch 45/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0126 - accuracy: 0.9982 - val_loss: 0.0081 - val_accuracy: 0.9996
# Epoch 46/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0122 - accuracy: 0.9983 - val_loss: 0.0079 - val_accuracy: 0.9996
# Epoch 47/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0122 - accuracy: 0.9983 - val_loss: 0.0075 - val_accuracy: 0.9996
# Epoch 48/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0115 - accuracy: 0.9984 - val_loss: 0.0073 - val_accuracy: 0.9996
# Epoch 49/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0110 - accuracy: 0.9984 - val_loss: 0.0070 - val_accuracy: 0.9996
# Epoch 50/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0106 - accuracy: 0.9985 - val_loss: 0.0068 - val_accuracy: 0.9996
# Epoch 51/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0109 - accuracy: 0.9985 - val_loss: 0.0067 - val_accuracy: 0.9996
# Epoch 52/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0104 - accuracy: 0.9985 - val_loss: 0.0065 - val_accuracy: 0.9996
# Epoch 53/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0102 - accuracy: 0.9986 - val_loss: 0.0063 - val_accuracy: 0.9996
# Epoch 54/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0099 - accuracy: 0.9986 - val_loss: 0.0063 - val_accuracy: 0.9996
# Epoch 55/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0098 - accuracy: 0.9986 - val_loss: 0.0060 - val_accuracy: 0.9996
# Epoch 56/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0095 - accuracy: 0.9987 - val_loss: 0.0059 - val_accuracy: 0.9996
# Epoch 57/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0093 - accuracy: 0.9988 - val_loss: 0.0058 - val_accuracy: 0.9996
# Epoch 58/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0090 - accuracy: 0.9988 - val_loss: 0.0056 - val_accuracy: 0.9996
# Epoch 59/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0088 - accuracy: 0.9989 - val_loss: 0.0056 - val_accuracy: 0.9996
# Epoch 60/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0086 - accuracy: 0.9989 - val_loss: 0.0054 - val_accuracy: 0.9996
# Epoch 61/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0084 - accuracy: 0.9990 - val_loss: 0.0053 - val_accuracy: 0.9996
# Epoch 62/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0084 - accuracy: 0.9989 - val_loss: 0.0052 - val_accuracy: 0.9996
# Epoch 63/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0083 - accuracy: 0.9990 - val_loss: 0.0051 - val_accuracy: 0.9996
# Epoch 64/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0083 - accuracy: 0.9991 - val_loss: 0.0051 - val_accuracy: 0.9996
# Epoch 65/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0078 - accuracy: 0.9991 - val_loss: 0.0050 - val_accuracy: 0.9996
# Epoch 66/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0079 - accuracy: 0.9991 - val_loss: 0.0048 - val_accuracy: 0.9996
# Epoch 67/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0079 - accuracy: 0.9991 - val_loss: 0.0048 - val_accuracy: 0.9996
# Epoch 68/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0077 - accuracy: 0.9992 - val_loss: 0.0047 - val_accuracy: 0.9996
# Epoch 69/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0073 - accuracy: 0.9992 - val_loss: 0.0047 - val_accuracy: 0.9996
# Epoch 70/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0073 - accuracy: 0.9991 - val_loss: 0.0045 - val_accuracy: 0.9996
# Epoch 71/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0071 - accuracy: 0.9992 - val_loss: 0.0045 - val_accuracy: 0.9996
# Epoch 72/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0070 - accuracy: 0.9992 - val_loss: 0.0045 - val_accuracy: 0.9996
# Epoch 73/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0070 - accuracy: 0.9992 - val_loss: 0.0044 - val_accuracy: 0.9996
# Epoch 74/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0070 - accuracy: 0.9992 - val_loss: 0.0044 - val_accuracy: 0.9996
# Epoch 75/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0072 - accuracy: 0.9992 - val_loss: 0.0043 - val_accuracy: 0.9996
# Epoch 76/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0068 - accuracy: 0.9992 - val_loss: 0.0042 - val_accuracy: 0.9996
# Epoch 77/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0067 - accuracy: 0.9992 - val_loss: 0.0042 - val_accuracy: 0.9996
# Epoch 78/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0072 - accuracy: 0.9992 - val_loss: 0.0042 - val_accuracy: 0.9996
# Epoch 79/100
# 11450/11450 [==============================] - 59s 5ms/step - loss: 0.0068 - accuracy: 0.9992 - val_loss: 0.0041 - val_accuracy: 0.9996
# Epoch 80/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0064 - accuracy: 0.9993 - val_loss: 0.0042 - val_accuracy: 0.9996
# Epoch 81/100
# 11450/11450 [==============================] - 59s 5ms/step - loss: 0.0065 - accuracy: 0.9993 - val_loss: 0.0041 - val_accuracy: 0.9996
# Epoch 82/100
# 11450/11450 [==============================] - 57s 5ms/step - loss: 0.0063 - accuracy: 0.9992 - val_loss: 0.0040 - val_accuracy: 0.9996
# Epoch 83/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0062 - accuracy: 0.9993 - val_loss: 0.0039 - val_accuracy: 0.9996
# Epoch 84/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0061 - accuracy: 0.9993 - val_loss: 0.0040 - val_accuracy: 0.9996
# Epoch 85/100
# 11450/11450 [==============================] - 61s 5ms/step - loss: 0.0060 - accuracy: 0.9993 - val_loss: 0.0039 - val_accuracy: 0.9996
# Epoch 86/100
# 11450/11450 [==============================] - 59s 5ms/step - loss: 0.0061 - accuracy: 0.9993 - val_loss: 0.0039 - val_accuracy: 0.9996
# Epoch 87/100
# 11450/11450 [==============================] - 59s 5ms/step - loss: 0.0058 - accuracy: 0.9994 - val_loss: 0.0038 - val_accuracy: 0.9996
# Epoch 88/100
# 11450/11450 [==============================] - 59s 5ms/step - loss: 0.0061 - accuracy: 0.9993 - val_loss: 0.0039 - val_accuracy: 0.9996
# Epoch 89/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0057 - accuracy: 0.9994 - val_loss: 0.0038 - val_accuracy: 0.9996
# Epoch 90/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0058 - accuracy: 0.9994 - val_loss: 0.0038 - val_accuracy: 0.9996
# Epoch 91/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0058 - accuracy: 0.9994 - val_loss: 0.0037 - val_accuracy: 0.9996
# Epoch 92/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0058 - accuracy: 0.9994 - val_loss: 0.0037 - val_accuracy: 0.9996
# Epoch 93/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0056 - accuracy: 0.9994 - val_loss: 0.0037 - val_accuracy: 0.9996
# Epoch 94/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0056 - accuracy: 0.9994 - val_loss: 0.0037 - val_accuracy: 0.9996
# Epoch 95/100
# 11450/11450 [==============================] - 59s 5ms/step - loss: 0.0058 - accuracy: 0.9994 - val_loss: 0.0037 - val_accuracy: 0.9996
# Epoch 96/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0054 - accuracy: 0.9994 - val_loss: 0.0036 - val_accuracy: 0.9996
# Epoch 97/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0056 - accuracy: 0.9995 - val_loss: 0.0036 - val_accuracy: 0.9996
# Epoch 98/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0053 - accuracy: 0.9995 - val_loss: 0.0036 - val_accuracy: 0.9996
# Epoch 99/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0054 - accuracy: 0.9995 - val_loss: 0.0035 - val_accuracy: 0.9996
# Epoch 100/100
# 11450/11450 [==============================] - 58s 5ms/step - loss: 0.0053 - accuracy: 0.9995 - val_loss: 0.0035 - val_accuracy: 0.9996

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("\nLoss: %4f, Accuracy: %.4f%%" % (loss, accuracy*100))
lstm_predict = model.predict_classes(X_test)
# Out:
# 9815/9815 [==============================] - 22s 2ms/step - loss: 0.0035 - accuracy: 0.9996
#
# Loss: 0.003532, Accuracy: 99.9627%
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
plt.plot(lstm_model.history['accuracy'])
plt.plot(lstm_model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('Akurasi')
plt.xlabel('Epoch')
plt.legend(['Data latih', 'Data uji'], loc='lower right')
plt.show()

# %%
plt.plot(lstm_model.history['loss'])
plt.plot(lstm_model.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Data latih', 'Data uji'], loc='upper right')
plt.show()

# %%
cm = confusion_matrix(y_test, lstm_predict)
print(cm)
tp = cm[0,0]
tn = cm[1,1]
fp = cm[0,1]
fn = cm[1,0]
# Out:
# [[107750    110]
#  [     7 206186]]

# %%
precision = tp / ( tp + fp)
recall = tp/(tp+fn)
f1=(2*precision*recall)/ (precision+recall)
akurasi = (tp+tn)/(tp+tn+fp+fn)
Sensitivity = tp/(tp + fn)

# %%
print ("precesion : ",precision)
print("recall : ",recall)
print ("F1 : ",f1)
print("sensitivity : ",Sensitivity )
print("akurasi : ",akurasi)
# Out:
# precesion :  0.9989801594659744
# recall :  0.9999350390229869
# F1 :  0.9994573711720319
# sensitivity :  0.9999350390229869
# akurasi :  0.9996274514174359

# %%
import keras
import seaborn as sns
from sklearn.metrics import roc_curve, auc

fpr_keras,tpr_keras, threshold =roc_curve(y_test, lstm_predict)
auc=auc(fpr_keras,tpr_keras)

plt.figure(1)
plt.plot([0,1],[0,1],'k--',color='yellow')
plt.plot(fpr_keras, tpr_keras, label="ROC CURVE {0:.4f}".format(auc))
plt.xlabel('false positive rate (spesitivity)')
plt.ylabel('true positive rate(sensitivity)')
plt.title('ROC CURVE')
plt.legend(loc='best')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from sklearn.metrics import average_precision_score
average_precision = average_precision_score(y_test, lstm_predict)

print('Average precision-recall score: {0:0.8f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.99945514

# %%
from inspect import signature
from sklearn.metrics import precision_recall_curve
precision, recall, threshold = precision_recall_curve(y_test, lstm_predict)
average_precision = average_precision_score(y_test, lstm_predict)
step_kwargs = ({'step': 'post'} if 'step' in signature(plt.fill_between).parameters else {})
plt.step(recall, precision, color='r', alpha=0.5, where='post')
plt.fill_between(recall, precision, alpha=0.5, color='w', **step_kwargs)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.5000, 1.0000])
plt.xlim([0.9980, 1.0000])
plt.title('2-class Precision-Recall curve: AP={0:0.8f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, '2-class Precision-Recall curve: AP=0.99945514')

# %%
lstm_predict.shape
# Out:
# (314053, 1)

# %%
lstm_predict
# Out:
# array([[0],
#        [1],
#        [0],
#        ...,
#        [1],
#        [1],
#        [0]], dtype=int32)

# %%
import pandas as pd
import numpy as np
lstm_predict.shape
# Out:
# (314053, 1)

# %%
dataset = pd.DataFrame()
dataset['lstm_predict'] = lstm_predict.tolist()

# %%
dataset.head()
# Out:
#   lstm_predict
# 0          [0]
# 1          [1]
# 2          [0]
# 3          [0]
# 4          [0]

# %%
hasil = pd.concat([testdata,dataset], axis=1)

# %%
hasil.to_csv(r'validasi_70_30.csv')

# %%
hasil = pd.read_csv('validasi_70_30.csv')

# %%
data = hasil.replace(to_replace = ["[1]"],value = 1)
data = data.replace(to_replace = ["[0]"],value = 0)

# %%
data.head(20)
# Out:
#     Unnamed: 0  Dst Port  Tot Fwd Pkts  ...  Fwd Act Data Pkts  Label  lstm_predict
# 0            0     12106             4  ...                  1      0             0
# 1            1         3             2  ...                  1      1             1
# 2            2      1430             4  ...                  1      0             0
# 3            3     12684             4  ...                  1      0             0
# 4            4      3564             4  ...                  1      0             0
# 5            5         3             1  ...                  0      1             1
# 6            6         3             2  ...                  1      1             1
# 7            7     10993             4  ...                  1      0             0
# 8            8      2494             4  ...                  1      0             0
# 9            9         3             1  ...                  0      1             1
# 10          10         3             2  ...                  1      1             1
# 11          11      6130             4  ...                  1      0             0
# 12          12         3             1  ...                  0      1             1
# 13          13      4483             4  ...                  1      0             0
# 14          14         3             2  ...                  1      1             1
# 15          15         3             2  ...                  1      1             1
# 16          16         3             1  ...                  0      1             1
# 17          17         3             2  ...                  1      1             1
# 18          18         3             2  ...                  1      1             1
# 19          19     13100             4  ...                  1      0             0
#
# [20 rows x 57 columns]

# %%
data_attack = data[data["Label"]==1]
data_normal = data[data["Label"]==0]

# %%
attack_error = data_attack[data_attack.loc[:,"Label"] != data_attack.loc[:,"lstm_predict"]]
normal_error = data_normal[data_normal.loc[:,"Label"] != data_normal.loc[:,"lstm_predict"]]

# %%
attack_error
# Out:
#         Unnamed: 0  Dst Port  ...  Label  lstm_predict
# 10948        10948         3  ...      1             0
# 26716        26716         3  ...      1             0
# 69515        69515         3  ...      1             0
# 151057      151057         3  ...      1             0
# 266404      266404         3  ...      1             0
# 272886      272886         3  ...      1             0
# 305236      305236         3  ...      1             0
#
# [7 rows x 57 columns]

# %%
normal_error.head(20)
# Out:
#        Unnamed: 0  Dst Port  ...  Label  lstm_predict
# 2043         2043         2  ...      0             1
# 6588         6588         3  ...      0             1
# 6788         6788        75  ...      0             1
# 18966       18966        27  ...      0             1
# 19220       19220         0  ...      0             1
# 20394       20394         7  ...      0             1
# 21144       21144         4  ...      0             1
# 23724       23724         1  ...      0             1
# 28941       28941        15  ...      0             1
# 31188       31188       764  ...      0             1
# 40808       40808         1  ...      0             1
# 41602       41602         7  ...      0             1
# 43739       43739       171  ...      0             1
# 45585       45585         0  ...      0             1
# 50019       50019        13  ...      0             1
# 55618       55618        11  ...      0             1
# 57596       57596         7  ...      0             1
# 66893       66893        23  ...      0             1
# 67630       67630         1  ...      0             1
# 72665       72665         1  ...      0             1
#
# [20 rows x 57 columns]
