# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive

# copy the .zip file into the root directory of cloud VM
# !cp /content/gdrive/MyDrive/dataset.zip ../

# unzip the zip file and its contents should now be in /darknet/data/obj
# !unzip ../dataset.zip
# Out:
# 'Colab Notebooks'   dataset.zip  'My Drive'
# Archive:  ../dataset.zip
#    creating: dataset/
#   inflating: dataset/testdata_10.csv
#   inflating: dataset/testdata_20.csv
#   inflating: dataset/testdata_30.csv
#   inflating: dataset/testdata_40.csv
#   inflating: dataset/testdata_50.csv
#   inflating: dataset/traindata_50.csv
#   inflating: dataset/traindata_60.csv
#   inflating: dataset/traindata_70.csv
#   inflating: dataset/traindata_80.csv
#   inflating: dataset/traindata_90.csv

# %%
from __future__ import print_function
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
np.random.seed(1337)  # for reproducibility
from keras.preprocessing import sequence
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Embedding
from keras.layers import LSTM, SimpleRNN, GRU
from keras.datasets import imdb
from keras.utils.np_utils import to_categorical
from sklearn.metrics import (precision_score, recall_score,f1_score, accuracy_score,mean_squared_error,mean_absolute_error)
from sklearn import metrics
from sklearn.preprocessing import Normalizer
import h5py
from keras import callbacks
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

# %%
traindata = pd.read_csv('dataset/traindata_50.csv')
testdata = pd.read_csv('dataset/testdata_50.csv')

# %%
traindata.drop(['Unnamed: 0','Timestamp'], axis = 1, inplace=True)
testdata.drop(['Unnamed: 0','Timestamp'], axis = 1, inplace=True)

# %%
traindata = traindata.replace(to_replace = ["DDOS attack-HOIC"],value = 1)
traindata = traindata.replace(to_replace = ["Benign"],value = 0)
testdata = testdata.replace(to_replace = ["DDOS attack-HOIC"],value = 1)
testdata = testdata.replace(to_replace = ["Benign"],value = 0)

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor1 = traindata.corr()
sns.heatmap(cor1, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
a = abs(cor1['Label'])
result = a[a > 0.1]
result
# Out:
# Dst Port             0.990309
# Tot Fwd Pkts         0.928242
# Tot Bwd Pkts         0.332358
# TotLen Fwd Pkts      0.963077
# TotLen Bwd Pkts      0.110003
# Fwd Pkt Len Max      0.964790
# Fwd Pkt Len Mean     0.907802
# Fwd Pkt Len Std      0.942623
# Bwd Pkt Len Max      0.109875
# Bwd Pkt Len Mean     0.478382
# Bwd Pkt Len Std      0.279612
# Flow Byts/s          0.687545
# Flow Pkts/s          0.320317
# Bwd IAT Min          0.106296
# Fwd Header Len       0.946162
# Bwd Header Len       0.256283
# Fwd Pkts/s           0.244122
# Bwd Pkts/s           0.446099
# Pkt Len Max          0.719146
# Pkt Len Mean         0.718912
# Pkt Len Std          0.718361
# Pkt Len Var          0.718267
# RST Flag Cnt         0.718132
# PSH Flag Cnt         0.718821
# ACK Flag Cnt         0.724065
# ECE Flag Cnt         0.718132
# Down/Up Ratio        0.311208
# Pkt Size Avg         0.718623
# Fwd Seg Size Avg     0.907802
# Bwd Seg Size Avg     0.478382
# Subflow Fwd Pkts     0.928242
# Subflow Fwd Byts     0.963077
# Subflow Bwd Pkts     0.332358
# Subflow Bwd Byts     0.110003
# Init Fwd Win Byts    0.706518
# Init Bwd Win Byts    0.995114
# Fwd Act Data Pkts    0.537464
# Label                1.000000
# Name: Label, dtype: float64

# %%
traindata.drop(['Protocol','Flow Byts/s','Flow Pkts/s','Pkt Len Min','Fwd Byts/b Avg','Fwd Pkts/b Avg','Fwd Blk Rate Avg','Bwd Byts/b Avg','Bwd Pkts/b Avg','Bwd Blk Rate Avg','Fwd Seg Size Min','Active Mean','Active Std','Active Max','Active Min','Idle Mean','Idle Std','Idle Max','Idle Min','FIN Flag Cnt','SYN Flag Cnt','URG Flag Cnt','CWE Flag Count','Flow Duration'], axis = 1, inplace=True)
testdata.drop(['Protocol','Flow Byts/s','Flow Pkts/s','Pkt Len Min','Fwd Byts/b Avg','Fwd Pkts/b Avg','Fwd Blk Rate Avg','Bwd Byts/b Avg','Bwd Pkts/b Avg','Bwd Blk Rate Avg','Fwd Seg Size Min','Active Mean','Active Std','Active Max','Active Min','Idle Mean','Idle Std','Idle Max','Idle Min','FIN Flag Cnt','SYN Flag Cnt','URG Flag Cnt','CWE Flag Count','Flow Duration'], axis = 1, inplace=True)

# %%
enc = LabelEncoder()
traindata = traindata.apply(enc.fit_transform)
testdata = testdata.apply(enc.fit_transform)

# %%
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523422 entries, 0 to 523421
# Data columns (total 55 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Dst Port           523422 non-null  int64
#  1   Tot Fwd Pkts       523422 non-null  int64
#  2   Tot Bwd Pkts       523422 non-null  int64
#  3   TotLen Fwd Pkts    523422 non-null  int64
#  4   TotLen Bwd Pkts    523422 non-null  int64
#  5   Fwd Pkt Len Max    523422 non-null  int64
#  6   Fwd Pkt Len Min    523422 non-null  int64
#  7   Fwd Pkt Len Mean   523422 non-null  int64
#  8   Fwd Pkt Len Std    523422 non-null  int64
#  9   Bwd Pkt Len Max    523422 non-null  int64
#  10  Bwd Pkt Len Min    523422 non-null  int64
#  11  Bwd Pkt Len Mean   523422 non-null  int64
#  12  Bwd Pkt Len Std    523422 non-null  int64
#  13  Flow IAT Mean      523422 non-null  int64
#  14  Flow IAT Std       523422 non-null  int64
#  15  Flow IAT Max       523422 non-null  int64
#  16  Flow IAT Min       523422 non-null  int64
#  17  Fwd IAT Tot        523422 non-null  int64
#  18  Fwd IAT Mean       523422 non-null  int64
#  19  Fwd IAT Std        523422 non-null  int64
#  20  Fwd IAT Max        523422 non-null  int64
#  21  Fwd IAT Min        523422 non-null  int64
#  22  Bwd IAT Tot        523422 non-null  int64
#  23  Bwd IAT Mean       523422 non-null  int64
#  24  Bwd IAT Std        523422 non-null  int64
#  25  Bwd IAT Max        523422 non-null  int64
#  26  Bwd IAT Min        523422 non-null  int64
#  27  Fwd PSH Flags      523422 non-null  int64
#  28  Bwd PSH Flags      523422 non-null  int64
#  29  Fwd URG Flags      523422 non-null  int64
#  30  Bwd URG Flags      523422 non-null  int64
#  31  Fwd Header Len     523422 non-null  int64
#  32  Bwd Header Len     523422 non-null  int64
#  33  Fwd Pkts/s         523422 non-null  int64
#  34  Bwd Pkts/s         523422 non-null  int64
#  35  Pkt Len Max        523422 non-null  int64
#  36  Pkt Len Mean       523422 non-null  int64
#  37  Pkt Len Std        523422 non-null  int64
#  38  Pkt Len Var        523422 non-null  int64
#  39  RST Flag Cnt       523422 non-null  int64
#  40  PSH Flag Cnt       523422 non-null  int64
#  41  ACK Flag Cnt       523422 non-null  int64
#  42  ECE Flag Cnt       523422 non-null  int64
#  43  Down/Up Ratio      523422 non-null  int64
#  44  Pkt Size Avg       523422 non-null  int64
#  45  Fwd Seg Size Avg   523422 non-null  int64
#  46  Bwd Seg Size Avg   523422 non-null  int64
#  47  Subflow Fwd Pkts   523422 non-null  int64
#  48  Subflow Fwd Byts   523422 non-null  int64
#  49  Subflow Bwd Pkts   523422 non-null  int64
#  50  Subflow Bwd Byts   523422 non-null  int64
#  51  Init Fwd Win Byts  523422 non-null  int64
#  52  Init Bwd Win Byts  523422 non-null  int64
#  53  Fwd Act Data Pkts  523422 non-null  int64
#  54  Label              523422 non-null  int64
# dtypes: int64(55)
# memory usage: 219.6 MB

# %%
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523422 entries, 0 to 523421
# Data columns (total 55 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Dst Port           523422 non-null  int64
#  1   Tot Fwd Pkts       523422 non-null  int64
#  2   Tot Bwd Pkts       523422 non-null  int64
#  3   TotLen Fwd Pkts    523422 non-null  int64
#  4   TotLen Bwd Pkts    523422 non-null  int64
#  5   Fwd Pkt Len Max    523422 non-null  int64
#  6   Fwd Pkt Len Min    523422 non-null  int64
#  7   Fwd Pkt Len Mean   523422 non-null  int64
#  8   Fwd Pkt Len Std    523422 non-null  int64
#  9   Bwd Pkt Len Max    523422 non-null  int64
#  10  Bwd Pkt Len Min    523422 non-null  int64
#  11  Bwd Pkt Len Mean   523422 non-null  int64
#  12  Bwd Pkt Len Std    523422 non-null  int64
#  13  Flow IAT Mean      523422 non-null  int64
#  14  Flow IAT Std       523422 non-null  int64
#  15  Flow IAT Max       523422 non-null  int64
#  16  Flow IAT Min       523422 non-null  int64
#  17  Fwd IAT Tot        523422 non-null  int64
#  18  Fwd IAT Mean       523422 non-null  int64
#  19  Fwd IAT Std        523422 non-null  int64
#  20  Fwd IAT Max        523422 non-null  int64
#  21  Fwd IAT Min        523422 non-null  int64
#  22  Bwd IAT Tot        523422 non-null  int64
#  23  Bwd IAT Mean       523422 non-null  int64
#  24  Bwd IAT Std        523422 non-null  int64
#  25  Bwd IAT Max        523422 non-null  int64
#  26  Bwd IAT Min        523422 non-null  int64
#  27  Fwd PSH Flags      523422 non-null  int64
#  28  Bwd PSH Flags      523422 non-null  int64
#  29  Fwd URG Flags      523422 non-null  int64
#  30  Bwd URG Flags      523422 non-null  int64
#  31  Fwd Header Len     523422 non-null  int64
#  32  Bwd Header Len     523422 non-null  int64
#  33  Fwd Pkts/s         523422 non-null  int64
#  34  Bwd Pkts/s         523422 non-null  int64
#  35  Pkt Len Max        523422 non-null  int64
#  36  Pkt Len Mean       523422 non-null  int64
#  37  Pkt Len Std        523422 non-null  int64
#  38  Pkt Len Var        523422 non-null  int64
#  39  RST Flag Cnt       523422 non-null  int64
#  40  PSH Flag Cnt       523422 non-null  int64
#  41  ACK Flag Cnt       523422 non-null  int64
#  42  ECE Flag Cnt       523422 non-null  int64
#  43  Down/Up Ratio      523422 non-null  int64
#  44  Pkt Size Avg       523422 non-null  int64
#  45  Fwd Seg Size Avg   523422 non-null  int64
#  46  Bwd Seg Size Avg   523422 non-null  int64
#  47  Subflow Fwd Pkts   523422 non-null  int64
#  48  Subflow Fwd Byts   523422 non-null  int64
#  49  Subflow Bwd Pkts   523422 non-null  int64
#  50  Subflow Bwd Byts   523422 non-null  int64
#  51  Init Fwd Win Byts  523422 non-null  int64
#  52  Init Bwd Win Byts  523422 non-null  int64
#  53  Fwd Act Data Pkts  523422 non-null  int64
#  54  Label              523422 non-null  int64
# dtypes: int64(55)
# memory usage: 219.6 MB

# %%
testdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523422 entries, 0 to 523421
# Data columns (total 55 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Dst Port           523422 non-null  int64
#  1   Tot Fwd Pkts       523422 non-null  int64
#  2   Tot Bwd Pkts       523422 non-null  int64
#  3   TotLen Fwd Pkts    523422 non-null  int64
#  4   TotLen Bwd Pkts    523422 non-null  int64
#  5   Fwd Pkt Len Max    523422 non-null  int64
#  6   Fwd Pkt Len Min    523422 non-null  int64
#  7   Fwd Pkt Len Mean   523422 non-null  int64
#  8   Fwd Pkt Len Std    523422 non-null  int64
#  9   Bwd Pkt Len Max    523422 non-null  int64
#  10  Bwd Pkt Len Min    523422 non-null  int64
#  11  Bwd Pkt Len Mean   523422 non-null  int64
#  12  Bwd Pkt Len Std    523422 non-null  int64
#  13  Flow IAT Mean      523422 non-null  int64
#  14  Flow IAT Std       523422 non-null  int64
#  15  Flow IAT Max       523422 non-null  int64
#  16  Flow IAT Min       523422 non-null  int64
#  17  Fwd IAT Tot        523422 non-null  int64
#  18  Fwd IAT Mean       523422 non-null  int64
#  19  Fwd IAT Std        523422 non-null  int64
#  20  Fwd IAT Max        523422 non-null  int64
#  21  Fwd IAT Min        523422 non-null  int64
#  22  Bwd IAT Tot        523422 non-null  int64
#  23  Bwd IAT Mean       523422 non-null  int64
#  24  Bwd IAT Std        523422 non-null  int64
#  25  Bwd IAT Max        523422 non-null  int64
#  26  Bwd IAT Min        523422 non-null  int64
#  27  Fwd PSH Flags      523422 non-null  int64
#  28  Bwd PSH Flags      523422 non-null  int64
#  29  Fwd URG Flags      523422 non-null  int64
#  30  Bwd URG Flags      523422 non-null  int64
#  31  Fwd Header Len     523422 non-null  int64
#  32  Bwd Header Len     523422 non-null  int64
#  33  Fwd Pkts/s         523422 non-null  int64
#  34  Bwd Pkts/s         523422 non-null  int64
#  35  Pkt Len Max        523422 non-null  int64
#  36  Pkt Len Mean       523422 non-null  int64
#  37  Pkt Len Std        523422 non-null  int64
#  38  Pkt Len Var        523422 non-null  int64
#  39  RST Flag Cnt       523422 non-null  int64
#  40  PSH Flag Cnt       523422 non-null  int64
#  41  ACK Flag Cnt       523422 non-null  int64
#  42  ECE Flag Cnt       523422 non-null  int64
#  43  Down/Up Ratio      523422 non-null  int64
#  44  Pkt Size Avg       523422 non-null  int64
#  45  Fwd Seg Size Avg   523422 non-null  int64
#  46  Bwd Seg Size Avg   523422 non-null  int64
#  47  Subflow Fwd Pkts   523422 non-null  int64
#  48  Subflow Fwd Byts   523422 non-null  int64
#  49  Subflow Bwd Pkts   523422 non-null  int64
#  50  Subflow Bwd Byts   523422 non-null  int64
#  51  Init Fwd Win Byts  523422 non-null  int64
#  52  Init Bwd Win Byts  523422 non-null  int64
#  53  Fwd Act Data Pkts  523422 non-null  int64
#  54  Label              523422 non-null  int64
# dtypes: int64(55)
# memory usage: 219.6 MB

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
data = ['Train Data','Test Data']
Label = [524287,522557]
ax.pie(Label,labels=data,autopct='%1.2f%%')
plt.show()

# %%
traindata.groupby('Label')['Label'].count()
# Out:
# Label
# 0    180622
# 1    342800
# Name: Label, dtype: int64

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
data = ['Benign','DDoS HTTP Flood']
Label = [180930,343357]
ax.pie(Label,labels=data,autopct='%1.2f%%')
plt.show()

# %%
testdata.groupby('Label')['Label'].count()
# Out:
# Label
# 0    180210
# 1    343212
# Name: Label, dtype: int64

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
data = ['Benign','DDoS HTTP Flood']
Label = [179903,342654]
ax.pie(Label,labels=data,autopct='%1.2f%%')
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
data = ['Benign','DDoS HTTP Flood']
Label = [360833,686012]
ax.pie(Label,labels=data,autopct='%1.2f%%')
plt.show()

# %%
X = traindata.iloc[:, 0:53]
Y = traindata.iloc[:, 54]
C = testdata.iloc[:, 54]
T = testdata.iloc[:, 0:53]

# %%
scaler = Normalizer().fit(X)
trainX = scaler.transform(X)

# %%
scaler = Normalizer().fit(T)
testT = scaler.transform(T)

# %%
y_train = np.array(Y)
y_test = np.array(C)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
X_test = np.reshape(testT, (testT.shape[0], 1, testT.shape[1]))

# %%
print(X_train.shape)
# Out:
# (523422, 1, 53)

# %%
batch_size = 64

# %%
model = Sequential()
model.add(LSTM(16,input_dim=53, return_sequences=True))  # try using a GRU instead, for fun
model.add(Dropout(0.1))
model.add(LSTM(8, return_sequences=False))  # try using a GRU instead, for fun
model.add(Dropout(0.1))
model.add(Dense(1))
model.add(Activation('sigmoid'))
print(model.get_config())
# Out:
# {'name': 'sequential', 'layers': [{'class_name': 'InputLayer', 'config': {'batch_input_shape': (None, None, 53), 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'lstm_input'}}, {'class_name': 'LSTM', 'config': {'name': 'lstm', 'trainable': True, 'batch_input_shape': (None, None, 53), 'dtype': 'float32', 'return_sequences': True, 'return_state': False, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False, 'units': 16, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'recurrent_initializer': {'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'unit_forget_bias': True, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 2}}, {'class_name': 'Dropout', 'config': {'name': 'dropout', 'trainable': True, 'dtype': 'float32', 'rate': 0.1, 'noise_shape': None, 'seed': None}}, {'class_name': 'LSTM', 'config': {'name': 'lstm_1', 'trainable': True, 'dtype': 'float32', 'return_sequences': False, 'return_state': False, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False, 'units': 8, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'recurrent_initializer': {'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'unit_forget_bias': True, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 2}}, {'class_name': 'Dropout', 'config': {'name': 'dropout_1', 'trainable': True, 'dtype': 'float32', 'rate': 0.1, 'noise_shape': None, 'seed': None}}, {'class_name': 'Dense', 'config': {'name': 'dense', 'trainable': True, 'dtype': 'float32', 'units': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Activation', 'config': {'name': 'activation', 'trainable': True, 'dtype': 'float32', 'activation': 'sigmoid'}}]}

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 16)          4480
# _________________________________________________________________
# dropout (Dropout)            (None, None, 16)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# _________________________________________________________________
# activation (Activation)      (None, 1)                 0
# =================================================================
# Total params: 5,289
# Trainable params: 5,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
import keras
model.compile(loss='binary_crossentropy',optimizer=keras.optimizers.SGD(learning_rate=0.001),metrics=['accuracy'])
csv_logger = CSVLogger('training_set_iranalysis.csv',separator=',', append=False)
lstm_model = model.fit(X_train, y_train, batch_size=64, epochs=100, validation_data=(X_test, y_test),callbacks=[csv_logger])
model.save("kddresults/lstm/fullmodel/lstm_model.hdf5")
# Out:
# Epoch 1/100
# 8179/8179 [==============================] - 83s 6ms/step - loss: 0.6668 - accuracy: 0.6422 - val_loss: 0.6418 - val_accuracy: 0.6557
# Epoch 2/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.6416 - accuracy: 0.6548 - val_loss: 0.6391 - val_accuracy: 0.6557
# Epoch 3/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.6386 - accuracy: 0.6555 - val_loss: 0.6365 - val_accuracy: 0.6557
# Epoch 4/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.6355 - accuracy: 0.6560 - val_loss: 0.6331 - val_accuracy: 0.6557
# Epoch 5/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.6316 - accuracy: 0.6564 - val_loss: 0.6283 - val_accuracy: 0.6557
# Epoch 6/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.6281 - accuracy: 0.6535 - val_loss: 0.6211 - val_accuracy: 0.6557
# Epoch 7/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.6195 - accuracy: 0.6545 - val_loss: 0.6096 - val_accuracy: 0.6557
# Epoch 8/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.6064 - accuracy: 0.6543 - val_loss: 0.5900 - val_accuracy: 0.6557
# Epoch 9/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.5832 - accuracy: 0.6555 - val_loss: 0.5559 - val_accuracy: 0.6557
# Epoch 10/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.5448 - accuracy: 0.6563 - val_loss: 0.5018 - val_accuracy: 0.6557
# Epoch 11/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.4898 - accuracy: 0.7239 - val_loss: 0.4397 - val_accuracy: 0.7939
# Epoch 12/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.4333 - accuracy: 0.7856 - val_loss: 0.3926 - val_accuracy: 0.8140
# Epoch 13/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.3952 - accuracy: 0.8009 - val_loss: 0.3638 - val_accuracy: 0.8237
# Epoch 14/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.3715 - accuracy: 0.8089 - val_loss: 0.3440 - val_accuracy: 0.8288
# Epoch 15/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.3534 - accuracy: 0.8131 - val_loss: 0.3225 - val_accuracy: 0.8317
# Epoch 16/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.3280 - accuracy: 0.8269 - val_loss: 0.2867 - val_accuracy: 0.8852
# Epoch 17/100
# 8179/8179 [==============================] - 50s 6ms/step - loss: 0.2898 - accuracy: 0.8751 - val_loss: 0.2507 - val_accuracy: 0.9096
# Epoch 18/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.2559 - accuracy: 0.8946 - val_loss: 0.2180 - val_accuracy: 0.9190
# Epoch 19/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.2246 - accuracy: 0.9097 - val_loss: 0.1857 - val_accuracy: 0.9359
# Epoch 20/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.1939 - accuracy: 0.9305 - val_loss: 0.1549 - val_accuracy: 0.9600
# Epoch 21/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.1648 - accuracy: 0.9481 - val_loss: 0.1273 - val_accuracy: 0.9702
# Epoch 22/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.1396 - accuracy: 0.9595 - val_loss: 0.1042 - val_accuracy: 0.9768
# Epoch 23/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.1184 - accuracy: 0.9670 - val_loss: 0.0854 - val_accuracy: 0.9824
# Epoch 24/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.1010 - accuracy: 0.9733 - val_loss: 0.0706 - val_accuracy: 0.9867
# Epoch 25/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0878 - accuracy: 0.9780 - val_loss: 0.0591 - val_accuracy: 0.9895
# Epoch 26/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0769 - accuracy: 0.9820 - val_loss: 0.0503 - val_accuracy: 0.9917
# Epoch 27/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0692 - accuracy: 0.9849 - val_loss: 0.0435 - val_accuracy: 0.9941
# Epoch 28/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0625 - accuracy: 0.9873 - val_loss: 0.0381 - val_accuracy: 0.9961
# Epoch 29/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0573 - accuracy: 0.9891 - val_loss: 0.0339 - val_accuracy: 0.9977
# Epoch 30/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0528 - accuracy: 0.9907 - val_loss: 0.0305 - val_accuracy: 0.9977
# Epoch 31/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0490 - accuracy: 0.9913 - val_loss: 0.0276 - val_accuracy: 0.9977
# Epoch 32/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0458 - accuracy: 0.9917 - val_loss: 0.0252 - val_accuracy: 0.9977
# Epoch 33/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0430 - accuracy: 0.9920 - val_loss: 0.0231 - val_accuracy: 0.9977
# Epoch 34/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0406 - accuracy: 0.9921 - val_loss: 0.0213 - val_accuracy: 0.9977
# Epoch 35/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0387 - accuracy: 0.9923 - val_loss: 0.0196 - val_accuracy: 0.9977
# Epoch 36/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0365 - accuracy: 0.9924 - val_loss: 0.0180 - val_accuracy: 0.9977
# Epoch 37/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0345 - accuracy: 0.9927 - val_loss: 0.0166 - val_accuracy: 0.9977
# Epoch 38/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0327 - accuracy: 0.9930 - val_loss: 0.0153 - val_accuracy: 0.9977
# Epoch 39/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0308 - accuracy: 0.9933 - val_loss: 0.0141 - val_accuracy: 0.9977
# Epoch 40/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0292 - accuracy: 0.9937 - val_loss: 0.0130 - val_accuracy: 0.9977
# Epoch 41/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0275 - accuracy: 0.9937 - val_loss: 0.0121 - val_accuracy: 0.9978
# Epoch 42/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0265 - accuracy: 0.9941 - val_loss: 0.0113 - val_accuracy: 0.9981
# Epoch 43/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0254 - accuracy: 0.9953 - val_loss: 0.0107 - val_accuracy: 0.9996
# Epoch 44/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0244 - accuracy: 0.9958 - val_loss: 0.0101 - val_accuracy: 0.9996
# Epoch 45/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0235 - accuracy: 0.9959 - val_loss: 0.0095 - val_accuracy: 0.9996
# Epoch 46/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0226 - accuracy: 0.9961 - val_loss: 0.0091 - val_accuracy: 0.9996
# Epoch 47/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0215 - accuracy: 0.9962 - val_loss: 0.0087 - val_accuracy: 0.9996
# Epoch 48/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0206 - accuracy: 0.9964 - val_loss: 0.0083 - val_accuracy: 0.9996
# Epoch 49/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0200 - accuracy: 0.9967 - val_loss: 0.0080 - val_accuracy: 0.9996
# Epoch 50/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0195 - accuracy: 0.9966 - val_loss: 0.0077 - val_accuracy: 0.9996
# Epoch 51/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0194 - accuracy: 0.9967 - val_loss: 0.0074 - val_accuracy: 0.9996
# Epoch 52/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0184 - accuracy: 0.9968 - val_loss: 0.0071 - val_accuracy: 0.9996
# Epoch 53/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0178 - accuracy: 0.9969 - val_loss: 0.0069 - val_accuracy: 0.9996
# Epoch 54/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0174 - accuracy: 0.9971 - val_loss: 0.0067 - val_accuracy: 0.9996
# Epoch 55/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0169 - accuracy: 0.9971 - val_loss: 0.0065 - val_accuracy: 0.9996
# Epoch 56/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0159 - accuracy: 0.9973 - val_loss: 0.0063 - val_accuracy: 0.9996
# Epoch 57/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0155 - accuracy: 0.9975 - val_loss: 0.0061 - val_accuracy: 0.9996
# Epoch 58/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0152 - accuracy: 0.9975 - val_loss: 0.0059 - val_accuracy: 0.9996
# Epoch 59/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0148 - accuracy: 0.9975 - val_loss: 0.0058 - val_accuracy: 0.9996
# Epoch 60/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0141 - accuracy: 0.9978 - val_loss: 0.0056 - val_accuracy: 0.9996
# Epoch 61/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0143 - accuracy: 0.9977 - val_loss: 0.0055 - val_accuracy: 0.9996
# Epoch 62/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0138 - accuracy: 0.9976 - val_loss: 0.0054 - val_accuracy: 0.9996
# Epoch 63/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0134 - accuracy: 0.9980 - val_loss: 0.0053 - val_accuracy: 0.9996
# Epoch 64/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0132 - accuracy: 0.9977 - val_loss: 0.0052 - val_accuracy: 0.9996
# Epoch 65/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0126 - accuracy: 0.9979 - val_loss: 0.0051 - val_accuracy: 0.9996
# Epoch 66/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0125 - accuracy: 0.9980 - val_loss: 0.0050 - val_accuracy: 0.9996
# Epoch 67/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0120 - accuracy: 0.9981 - val_loss: 0.0049 - val_accuracy: 0.9996
# Epoch 68/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0119 - accuracy: 0.9981 - val_loss: 0.0048 - val_accuracy: 0.9996
# Epoch 69/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0121 - accuracy: 0.9980 - val_loss: 0.0047 - val_accuracy: 0.9996
# Epoch 70/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0117 - accuracy: 0.9981 - val_loss: 0.0046 - val_accuracy: 0.9996
# Epoch 71/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0113 - accuracy: 0.9982 - val_loss: 0.0045 - val_accuracy: 0.9996
# Epoch 72/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0110 - accuracy: 0.9983 - val_loss: 0.0045 - val_accuracy: 0.9996
# Epoch 73/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0108 - accuracy: 0.9983 - val_loss: 0.0044 - val_accuracy: 0.9996
# Epoch 74/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0106 - accuracy: 0.9984 - val_loss: 0.0043 - val_accuracy: 0.9996
# Epoch 75/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0103 - accuracy: 0.9985 - val_loss: 0.0043 - val_accuracy: 0.9996
# Epoch 76/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0102 - accuracy: 0.9984 - val_loss: 0.0042 - val_accuracy: 0.9996
# Epoch 77/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0101 - accuracy: 0.9985 - val_loss: 0.0042 - val_accuracy: 0.9996
# Epoch 78/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0097 - accuracy: 0.9987 - val_loss: 0.0041 - val_accuracy: 0.9996
# Epoch 79/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0096 - accuracy: 0.9986 - val_loss: 0.0041 - val_accuracy: 0.9996
# Epoch 80/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0094 - accuracy: 0.9986 - val_loss: 0.0040 - val_accuracy: 0.9996
# Epoch 81/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0092 - accuracy: 0.9987 - val_loss: 0.0040 - val_accuracy: 0.9996
# Epoch 82/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0097 - accuracy: 0.9985 - val_loss: 0.0039 - val_accuracy: 0.9996
# Epoch 83/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0092 - accuracy: 0.9988 - val_loss: 0.0039 - val_accuracy: 0.9996
# Epoch 84/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0091 - accuracy: 0.9987 - val_loss: 0.0038 - val_accuracy: 0.9996
# Epoch 85/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0089 - accuracy: 0.9987 - val_loss: 0.0038 - val_accuracy: 0.9996
# Epoch 86/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0090 - accuracy: 0.9987 - val_loss: 0.0038 - val_accuracy: 0.9996
# Epoch 87/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0082 - accuracy: 0.9989 - val_loss: 0.0037 - val_accuracy: 0.9996
# Epoch 88/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0084 - accuracy: 0.9988 - val_loss: 0.0037 - val_accuracy: 0.9996
# Epoch 89/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0085 - accuracy: 0.9987 - val_loss: 0.0037 - val_accuracy: 0.9996
# Epoch 90/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0082 - accuracy: 0.9989 - val_loss: 0.0036 - val_accuracy: 0.9996
# Epoch 91/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0082 - accuracy: 0.9989 - val_loss: 0.0036 - val_accuracy: 0.9996
# Epoch 92/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0079 - accuracy: 0.9990 - val_loss: 0.0036 - val_accuracy: 0.9996
# Epoch 93/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0081 - accuracy: 0.9990 - val_loss: 0.0035 - val_accuracy: 0.9996
# Epoch 94/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0079 - accuracy: 0.9990 - val_loss: 0.0035 - val_accuracy: 0.9996
# Epoch 95/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0078 - accuracy: 0.9990 - val_loss: 0.0035 - val_accuracy: 0.9996
# Epoch 96/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0078 - accuracy: 0.9991 - val_loss: 0.0035 - val_accuracy: 0.9996
# Epoch 97/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0077 - accuracy: 0.9990 - val_loss: 0.0034 - val_accuracy: 0.9996
# Epoch 98/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0074 - accuracy: 0.9991 - val_loss: 0.0034 - val_accuracy: 0.9996
# Epoch 99/100
# 8179/8179 [==============================] - 49s 6ms/step - loss: 0.0074 - accuracy: 0.9990 - val_loss: 0.0034 - val_accuracy: 0.9996
# Epoch 100/100
# 8179/8179 [==============================] - 48s 6ms/step - loss: 0.0076 - accuracy: 0.9990 - val_loss: 0.0034 - val_accuracy: 0.9996

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("\nLoss: %.4f, Accuracy: %.4f%%" % (loss, accuracy*100))
lstm_predict = model.predict_classes(X_test)
# Out:
# 16357/16357 [==============================] - 36s 2ms/step - loss: 0.0034 - accuracy: 0.9996
#
# Loss: 0.0034, Accuracy: 99.9641%
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
plt.plot(lstm_model.history['accuracy'])
plt.plot(lstm_model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('Akurasi')
plt.xlabel('Epoch')
plt.legend(['Data latih', 'Data uji'], loc='lower right')
plt.show()

# %%
plt.plot(lstm_model.history['loss'])
plt.plot(lstm_model.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Data latih', 'Data uji'], loc='upper right')
plt.show()

# %%
cm = confusion_matrix(y_test, lstm_predict)
print(cm)
tp = cm[0,0]
tn = cm[1,1]
fp = cm[0,1]
fn = cm[1,0]
# Out:
# [[180029    181]
#  [     7 343205]]

# %%
precision = tp / ( tp + fp)
recall = tp/(tp+fn)
f1=(2*precision*recall)/ (precision+recall)
akurasi = (tp+tn)/(tp+tn+fp+fn)
Sensitivity = tp/(tp + fn)

# %%
print ("precesion : ",precision)
print("recall : ",recall)
print ("F1 : ",f1)
print("sensitivity : ",Sensitivity )
print("akurasi : ",akurasi)
# Out:
# precesion :  0.9989956162255147
# recall :  0.9999611188873336
# F1 :  0.9994781343859473
# sensitivity :  0.9999611188873336
# akurasi :  0.9996408251850324

# %%
import keras
import seaborn as sns
from sklearn.metrics import roc_curve, auc

fpr_keras,tpr_keras, threshold =roc_curve(y_test, lstm_predict)
auc=auc(fpr_keras,tpr_keras)

plt.figure(1)
plt.plot([0,1],[0,1],'k--',color='yellow')
plt.plot(fpr_keras, tpr_keras, label="ROC CURVE {0:.4f}".format(auc))
plt.xlabel('false positive rate (spesitivity)')
plt.ylabel('true positive rate(sensitivity)')
plt.title('ROC CURVE')
plt.legend(loc='best')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from sklearn.metrics import average_precision_score
average_precision = average_precision_score(y_test, lstm_predict)

print('Average precision-recall score: {0:0.8f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.99946589

# %%
from inspect import signature
from sklearn.metrics import precision_recall_curve
precision, recall, threshold = precision_recall_curve(y_test, lstm_predict)
average_precision = average_precision_score(y_test, lstm_predict)
step_kwargs = ({'step': 'post'} if 'step' in signature(plt.fill_between).parameters else {})
plt.step(recall, precision, color='r', alpha=0.5, where='post')
plt.fill_between(recall, precision, alpha=0.5, color='w', **step_kwargs)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.5000, 1.0000])
plt.xlim([0.9980, 1.0000])
plt.title('2-class Precision-Recall curve: AP={0:0.8f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, '2-class Precision-Recall curve: AP=0.99946589')

# %%
lstm_predict
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [1],
#        [1],
#        [0]], dtype=int32)

# %%
import pandas as pd
import numpy as np
lstm_predict.shape
# Out:
# (523422, 1)

# %%
type(lstm_predict)
# Out:
# numpy.ndarray

# %%
dataset = pd.DataFrame()
dataset['lstm_predict'] = lstm_predict.tolist()

# %%
dataset.head()
# Out:
#   lstm_predict
# 0          [1]
# 1          [1]
# 2          [1]
# 3          [1]
# 4          [1]

# %%
hasil = pd.concat([testdata,dataset], axis=1)

# %%
hasil
# Out:
#         Dst Port  Tot Fwd Pkts  ...  Label  lstm_predict
# 0              4             2  ...      1           [1]
# 1              4             1  ...      1           [1]
# 2              4             1  ...      1           [1]
# 3              4             1  ...      1           [1]
# 4              4             1  ...      1           [1]
# ...          ...           ...  ...    ...           ...
# 523417     11054             4  ...      0           [0]
# 523418         4             1  ...      1           [1]
# 523419         4             1  ...      1           [1]
# 523420         4             1  ...      1           [1]
# 523421     11304             4  ...      0           [0]
#
# [523422 rows x 56 columns]

# %%
hasil.to_csv(r'validasi_50_50.csv')

# %%
hasil = pd.read_csv('validasi_50_50.csv')

# %%
data = hasil.replace(to_replace = ["[1]"],value = 1)
data = data.replace(to_replace = ["[0]"],value = 0)

# %%
data.head(20)
# Out:
#     Unnamed: 0  Dst Port  Tot Fwd Pkts  ...  Fwd Act Data Pkts  Label  lstm_predict
# 0            0         4             2  ...                  1      1             1
# 1            1         4             1  ...                  0      1             1
# 2            2         4             1  ...                  0      1             1
# 3            3         4             1  ...                  0      1             1
# 4            4         4             1  ...                  0      1             1
# 5            5         4             2  ...                  1      1             1
# 6            6      1532             4  ...                  1      0             0
# 7            7      3719             4  ...                  1      0             0
# 8            8      6462             4  ...                  1      0             0
# 9            9      3874             4  ...                  1      0             0
# 10          10      3095             4  ...                  1      0             0
# 11          11         4             2  ...                  1      1             1
# 12          12      3950             4  ...                  1      0             0
# 13          13     15942             4  ...                  1      0             0
# 14          14      6336             4  ...                  1      0             0
# 15          15         4             1  ...                  0      1             1
# 16          16         4             2  ...                  1      1             1
# 17          17         4             1  ...                  0      1             1
# 18          18      5002             4  ...                  1      0             0
# 19          19      5003             4  ...                  1      0             0
#
# [20 rows x 57 columns]

# %%
data_attack = data[data["Label"]==1]
data_normal = data[data["Label"]==0]

# %%
attack_error = data_attack[data_attack.loc[:,"Label"] != data_attack.loc[:,"lstm_predict"]]
normal_error = data_normal[data_normal.loc[:,"Label"] != data_normal.loc[:,"lstm_predict"]]

# %%
attack_error
# Out:
#         Unnamed: 0  Dst Port  ...  Label  lstm_predict
# 76559        76559         4  ...      1             0
# 220317      220317         4  ...      1             0
# 236085      236085         4  ...      1             0
# 360426      360426         4  ...      1             0
# 400794      400794         4  ...      1             0
# 482255      482255         4  ...      1             0
# 514605      514605         4  ...      1             0
#
# [7 rows x 57 columns]

# %%
normal_error.head(20)
# Out:
#        Unnamed: 0  Dst Port  ...  Label  lstm_predict
# 3320         3320       132  ...      0             1
# 9066         9066         2  ...      0             1
# 10007       10007        17  ...      0             1
# 11705       11705         1  ...      0             1
# 12366       12366        44  ...      0             1
# 13717       13717         9  ...      0             1
# 14350       14350      1545  ...      0             1
# 16429       16429         0  ...      0             1
# 16963       16963        76  ...      0             1
# 19012       19012         6  ...      0             1
# 23760       23760        45  ...      0             1
# 24481       24481         1  ...      0             1
# 26960       26960        10  ...      0             1
# 29410       29410        40  ...      0             1
# 31019       31019         1  ...      0             1
# 33081       33081         2  ...      0             1
# 33859       33859         1  ...      0             1
# 35201       35201         2  ...      0             1
# 40263       40263        34  ...      0             1
# 42926       42926        19  ...      0             1
#
# [20 rows x 57 columns]
